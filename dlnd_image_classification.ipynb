# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 2
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 2:
# Samples: 10000
# Label Counts: {0: 984, 1: 1007, 2: 1010, 3: 995, 4: 1010, 5: 988, 6: 1008, 7: 1026, 8: 987, 9: 985}
# First 20 Labels: [1, 6, 6, 8, 8, 3, 4, 6, 0, 6, 0, 3, 6, 6, 5, 4, 8, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 3 Max Value: 219
# Image - Shape: (32, 32, 3)
# Label - Label Id: 3 Name: cat

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    return np.divide(x, 255)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
from sklearn import preprocessing
lb = preprocessing.LabelBinarizer()

def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    try:
        lb.classes_
    except AttributeError:
        lb.fit(x)
    return lb.transform(x)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# If you're finding it hard to dedicate enough time for this course a week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) to build each layer, except "Convolutional & Max Pooling" layer.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# If you would like to get the most of this course, try to solve all the problems without TF Layers.  Let's begin!
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a bach of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    x = tf.placeholder(tf.float32, [None, image_shape[0], image_shape[1], 3], name='x')
    return x


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    y = tf.placeholder(tf.float32, [None, n_classes], name='y')
    return y


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    k = tf.placeholder(tf.float32, name='keep_prob')
    return k


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# Note: You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for this layer.  You're free to use any TensorFlow package for all the other layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides, conv_padding = 'SAME', mpool_padding = 'SAME'):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    #x = tf.contrib.layers.conv2d(x_tensor, conv_num_outputs, conv_ksize, conv_strides, 'SAME')
    #return tf.contrib.layers.max_pool2d(x, pool_ksize, pool_strides, 'SAME')
    
    #conv_padding, mpool_padding = 'SAME', 'SAME'
    
    depth = x_tensor.shape[3].value
    
    W1 = tf.Variable(tf.truncated_normal([conv_ksize[0], conv_ksize[1], depth, conv_num_outputs], stddev=0.1))
    b1 = tf.Variable(tf.zeros(conv_num_outputs))
    
    x1 = tf.nn.conv2d(
        x_tensor,
        W1,
        strides=[1, conv_strides[0], conv_strides[1], 1],
        padding = conv_padding
    )
    
    x2 = tf.nn.bias_add(x1, b1)
    x2 = tf.nn.relu(x2)
    
    out = tf.nn.max_pool(
        x2,
        ksize=[1, pool_ksize[0], pool_ksize[1], 1],
        strides=[1, pool_strides[0], pool_strides[1], 1],
        padding = mpool_padding
    )
    
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). You can use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for this layer.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    #return tf.contrib.layers.flatten(x_tensor)
    tlen = 1
    for i in x_tensor.shape.as_list()[1:]:
        tlen *= i   
    return tf.reshape(x_tensor, [-1, tlen])

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). You can use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for this layer.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    fW = tf.Variable(tf.truncated_normal([x_tensor.shape.as_list()[1], num_outputs], stddev=0.1))
    #fb = tf.Variable(tf.truncated_normal([num_outputs]))
    fb = tf.Variable(tf.zeros(num_outputs))
    fy = tf.add(tf.matmul(x_tensor, fW), fb)
    return tf.nn.relu(fy)
    #return tf.nn.sigmoid(fy)
    #return y


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). You can use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for this layer.
#
# Note: Activation, softmax, or cross entropy shouldn't be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    #return tf.contrib.layers.fully_connected(x_tensor, num_outputs, activation_fn=None)
    oW = tf.Variable(tf.truncated_normal([x_tensor.shape.as_list()[1], num_outputs], stddev=0.1))
    #b = tf.Variable(tf.random_normal([num_outputs]))
    ob = tf.Variable(tf.zeros(num_outputs))
    return tf.add(tf.matmul(x_tensor, oW), ob)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    x0 = conv2d_maxpool(x, 40,  (3,3), (1,1),  (2,2), (2,2), 'SAME')
    x0 = conv2d_maxpool(x0, 80,  (3,3), (1,1),  (2,2), (2,2), 'SAME')
    x0 = tf.nn.dropout(x0, keep_prob)
    x0 = conv2d_maxpool(x0, 256,  (3,3), (1,1),  (2,2), (2,2), 'SAME')
    
    x1 = conv2d_maxpool(x, 40,  (3,3), (1,1),  (2,2), (2,2), 'SAME')
    x1 = conv2d_maxpool(x1, 80,  (3,3), (1,1),  (2,2), (2,2), 'SAME')
    x1 = tf.nn.dropout(x1, keep_prob)
    x1 = conv2d_maxpool(x1, 256,  (3,3), (1,1),  (2,2), (2,2), 'SAME')
    
    x2 = conv2d_maxpool(x, 20,  (3,3), (1,1),  (2,2), (2,2), 'SAME')
    x2 = conv2d_maxpool(x2, 40,  (3,3), (1,1),  (2,2), (2,2), 'SAME')
    x2 = tf.nn.dropout(x2, keep_prob)
    x2 = conv2d_maxpool(x2, 128,  (3,3), (1,1),  (2,2), (2,2), 'SAME')
    
    x3 = conv2d_maxpool(x, 40,  (3,3), (1,1),  (2,2), (2,2), 'SAME')
    x3 = conv2d_maxpool(x3, 80,  (3,3), (1,1),  (2,2), (2,2), 'SAME')
    x3 = tf.nn.dropout(x3, keep_prob)
    x3 = conv2d_maxpool(x3, 256,  (3,3), (1,1),  (2,2), (2,2), 'SAME')
    

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    
    x0 = flatten(x0)
    x1 = flatten(x1)
    x2 = flatten(x2)
    x3 = flatten(x3)
    
    xs = tf.concat([x0, x1, x2, x3], 1)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    xs = fully_conn(xs, 1024)
    xs = tf.nn.dropout(xs, keep_prob)
    xs = fully_conn(xs, 256)
    xs = tf.nn.dropout(xs, keep_prob)
    xs = fully_conn(xs, 64)
    xs = tf.nn.dropout(xs, keep_prob)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    xs = output(xs, 10)
    
    
    # TODO: return output
    return xs


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    session.run(optimizer, feed_dict={x: feature_batch, y: label_batch, keep_prob: keep_probability})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    loss = session.run(cost, feed_dict={x: feature_batch, y: label_batch, keep_prob: 1.})
    acc = session.run(accuracy, feed_dict={x: valid_features, y: valid_labels, keep_prob: 1.})
    out_str = 'Loss: {:>10.4f} Validation Accuracy: {:.6f}'
    print(out_str.format(loss, acc))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 200
batch_size = 150
keep_probability = .5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.3000 Validation Accuracy: 0.123600
# Epoch  2, CIFAR-10 Batch 1:  Loss:     2.2952 Validation Accuracy: 0.141800
# Epoch  3, CIFAR-10 Batch 1:  Loss:     2.2491 Validation Accuracy: 0.159200
# Epoch  4, CIFAR-10 Batch 1:  Loss:     2.1935 Validation Accuracy: 0.179600
# Epoch  5, CIFAR-10 Batch 1:  Loss:     2.0884 Validation Accuracy: 0.251400
# Epoch  6, CIFAR-10 Batch 1:  Loss:     1.9917 Validation Accuracy: 0.257400
# Epoch  7, CIFAR-10 Batch 1:  Loss:     1.9306 Validation Accuracy: 0.326400
# Epoch  8, CIFAR-10 Batch 1:  Loss:     1.8490 Validation Accuracy: 0.327000
# Epoch  9, CIFAR-10 Batch 1:  Loss:     1.7974 Validation Accuracy: 0.374600
# Epoch 10, CIFAR-10 Batch 1:  Loss:     1.7859 Validation Accuracy: 0.356000
# Epoch 11, CIFAR-10 Batch 1:  Loss:     1.7373 Validation Accuracy: 0.372000
# Epoch 12, CIFAR-10 Batch 1:  Loss:     1.6675 Validation Accuracy: 0.408800
# Epoch 13, CIFAR-10 Batch 1:  Loss:     1.6214 Validation Accuracy: 0.420200
# Epoch 14, CIFAR-10 Batch 1:  Loss:     1.5852 Validation Accuracy: 0.427000
# Epoch 15, CIFAR-10 Batch 1:  Loss:     1.5463 Validation Accuracy: 0.433600
# Epoch 16, CIFAR-10 Batch 1:  Loss:     1.5165 Validation Accuracy: 0.452800
# Epoch 17, CIFAR-10 Batch 1:  Loss:     1.4684 Validation Accuracy: 0.485800
# Epoch 18, CIFAR-10 Batch 1:  Loss:     1.4455 Validation Accuracy: 0.488800
# Epoch 19, CIFAR-10 Batch 1:  Loss:     1.4292 Validation Accuracy: 0.465600
# Epoch 20, CIFAR-10 Batch 1:  Loss:     1.3617 Validation Accuracy: 0.503000
# Epoch 21, CIFAR-10 Batch 1:  Loss:     1.3176 Validation Accuracy: 0.517200
# Epoch 22, CIFAR-10 Batch 1:  Loss:     1.2692 Validation Accuracy: 0.523400
# Epoch 23, CIFAR-10 Batch 1:  Loss:     1.2456 Validation Accuracy: 0.530800
# Epoch 24, CIFAR-10 Batch 1:  Loss:     1.2030 Validation Accuracy: 0.523800
# Epoch 25, CIFAR-10 Batch 1:  Loss:     1.1771 Validation Accuracy: 0.542200
# Epoch 26, CIFAR-10 Batch 1:  Loss:     1.1271 Validation Accuracy: 0.544200
# Epoch 27, CIFAR-10 Batch 1:  Loss:     1.1158 Validation Accuracy: 0.540000
# Epoch 28, CIFAR-10 Batch 1:  Loss:     1.0993 Validation Accuracy: 0.546400
# Epoch 29, CIFAR-10 Batch 1:  Loss:     1.0386 Validation Accuracy: 0.567800
# Epoch 30, CIFAR-10 Batch 1:  Loss:     1.0314 Validation Accuracy: 0.558000
# Epoch 31, CIFAR-10 Batch 1:  Loss:     1.0018 Validation Accuracy: 0.581000
# Epoch 32, CIFAR-10 Batch 1:  Loss:     0.9748 Validation Accuracy: 0.561800
# Epoch 33, CIFAR-10 Batch 1:  Loss:     0.9089 Validation Accuracy: 0.593000
# Epoch 34, CIFAR-10 Batch 1:  Loss:     0.8558 Validation Accuracy: 0.604000
# Epoch 35, CIFAR-10 Batch 1:  Loss:     0.8737 Validation Accuracy: 0.610400
# Epoch 36, CIFAR-10 Batch 1:  Loss:     0.7827 Validation Accuracy: 0.607800
# Epoch 37, CIFAR-10 Batch 1:  Loss:     0.7889 Validation Accuracy: 0.602200
# Epoch 38, CIFAR-10 Batch 1:  Loss:     0.7924 Validation Accuracy: 0.597800
# Epoch 39, CIFAR-10 Batch 1:  Loss:     0.7722 Validation Accuracy: 0.609800
# Epoch 40, CIFAR-10 Batch 1:  Loss:     0.7179 Validation Accuracy: 0.624400
# Epoch 41, CIFAR-10 Batch 1:  Loss:     0.7596 Validation Accuracy: 0.607400
# Epoch 42, CIFAR-10 Batch 1:  Loss:     0.7340 Validation Accuracy: 0.627800
# Epoch 43, CIFAR-10 Batch 1:  Loss:     0.6726 Validation Accuracy: 0.614400
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.6406 Validation Accuracy: 0.630400
# Epoch 45, CIFAR-10 Batch 1:  Loss:     0.6683 Validation Accuracy: 0.625200
# Epoch 46, CIFAR-10 Batch 1:  Loss:     0.6446 Validation Accuracy: 0.621200
# Epoch 47, CIFAR-10 Batch 1:  Loss:     0.6320 Validation Accuracy: 0.627600
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.5900 Validation Accuracy: 0.641400
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.5921 Validation Accuracy: 0.628000
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.5526 Validation Accuracy: 0.627800
# Epoch 51, CIFAR-10 Batch 1:  Loss:     0.5298 Validation Accuracy: 0.633200
# Epoch 52, CIFAR-10 Batch 1:  Loss:     0.5372 Validation Accuracy: 0.647600
# Epoch 53, CIFAR-10 Batch 1:  Loss:     0.5884 Validation Accuracy: 0.634800
# Epoch 54, CIFAR-10 Batch 1:  Loss:     0.4976 Validation Accuracy: 0.648600
# Epoch 55, CIFAR-10 Batch 1:  Loss:     0.4819 Validation Accuracy: 0.650800
# Epoch 56, CIFAR-10 Batch 1:  Loss:     0.4323 Validation Accuracy: 0.646000
# Epoch 57, CIFAR-10 Batch 1:  Loss:     0.4619 Validation Accuracy: 0.645400
# Epoch 58, CIFAR-10 Batch 1:  Loss:     0.5059 Validation Accuracy: 0.618000
# Epoch 59, CIFAR-10 Batch 1:  Loss:     0.4148 Validation Accuracy: 0.648600
# Epoch 60, CIFAR-10 Batch 1:  Loss:     0.3858 Validation Accuracy: 0.633200
# Epoch 61, CIFAR-10 Batch 1:  Loss:     0.4587 Validation Accuracy: 0.620600
# Epoch 62, CIFAR-10 Batch 1:  Loss:     0.3816 Validation Accuracy: 0.640200
# Epoch 63, CIFAR-10 Batch 1:  Loss:     0.3889 Validation Accuracy: 0.639600
# Epoch 64, CIFAR-10 Batch 1:  Loss:     0.3373 Validation Accuracy: 0.642800
# Epoch 65, CIFAR-10 Batch 1:  Loss:     0.3844 Validation Accuracy: 0.632400
# Epoch 66, CIFAR-10 Batch 1:  Loss:     0.3535 Validation Accuracy: 0.631400
# Epoch 67, CIFAR-10 Batch 1:  Loss:     0.3443 Validation Accuracy: 0.639200
# Epoch 68, CIFAR-10 Batch 1:  Loss:     0.2828 Validation Accuracy: 0.663400
# Epoch 69, CIFAR-10 Batch 1:  Loss:     0.3049 Validation Accuracy: 0.637600
# Epoch 70, CIFAR-10 Batch 1:  Loss:     0.2642 Validation Accuracy: 0.644400
# Epoch 71, CIFAR-10 Batch 1:  Loss:     0.3079 Validation Accuracy: 0.626200
# Epoch 72, CIFAR-10 Batch 1:  Loss:     0.2962 Validation Accuracy: 0.638800
# Epoch 73, CIFAR-10 Batch 1:  Loss:     0.2446 Validation Accuracy: 0.645600
# Epoch 74, CIFAR-10 Batch 1:  Loss:     0.2376 Validation Accuracy: 0.657200
# Epoch 75, CIFAR-10 Batch 1:  Loss:     0.2509 Validation Accuracy: 0.639000
# Epoch 76, CIFAR-10 Batch 1:  Loss:     0.2505 Validation Accuracy: 0.642200
# Epoch 77, CIFAR-10 Batch 1:  Loss:     0.2059 Validation Accuracy: 0.652600
# Epoch 78, CIFAR-10 Batch 1:  Loss:     0.1880 Validation Accuracy: 0.651600
# Epoch 79, CIFAR-10 Batch 1:  Loss:     0.1859 Validation Accuracy: 0.665200
# Epoch 80, CIFAR-10 Batch 1:  Loss:     0.2066 Validation Accuracy: 0.653800
# Epoch 81, CIFAR-10 Batch 1:  Loss:     0.1899 Validation Accuracy: 0.659800
# Epoch 82, CIFAR-10 Batch 1:  Loss:     0.1868 Validation Accuracy: 0.644400
# Epoch 83, CIFAR-10 Batch 1:  Loss:     0.1528 Validation Accuracy: 0.664000
# Epoch 84, CIFAR-10 Batch 1:  Loss:     0.1381 Validation Accuracy: 0.652600
# Epoch 85, CIFAR-10 Batch 1:  Loss:     0.1307 Validation Accuracy: 0.652200
# Epoch 86, CIFAR-10 Batch 1:  Loss:     0.1132 Validation Accuracy: 0.657400
# Epoch 87, CIFAR-10 Batch 1:  Loss:     0.0998 Validation Accuracy: 0.674600
# Epoch 88, CIFAR-10 Batch 1:  Loss:     0.1145 Validation Accuracy: 0.661400
# Epoch 89, CIFAR-10 Batch 1:  Loss:     0.0990 Validation Accuracy: 0.666800
# Epoch 90, CIFAR-10 Batch 1:  Loss:     0.1317 Validation Accuracy: 0.664000
# Epoch 91, CIFAR-10 Batch 1:  Loss:     0.1023 Validation Accuracy: 0.663800
# Epoch 92, CIFAR-10 Batch 1:  Loss:     0.1109 Validation Accuracy: 0.663400
# Epoch 93, CIFAR-10 Batch 1:  Loss:     0.1038 Validation Accuracy: 0.654200
# Epoch 94, CIFAR-10 Batch 1:  Loss:     0.0750 Validation Accuracy: 0.657000
# Epoch 95, CIFAR-10 Batch 1:  Loss:     0.0664 Validation Accuracy: 0.666200
# Epoch 96, CIFAR-10 Batch 1:  Loss:     0.0792 Validation Accuracy: 0.654800
# Epoch 97, CIFAR-10 Batch 1:  Loss:     0.0611 Validation Accuracy: 0.671400
# Epoch 98, CIFAR-10 Batch 1:  Loss:     0.0628 Validation Accuracy: 0.660800
# Epoch 99, CIFAR-10 Batch 1:  Loss:     0.0569 Validation Accuracy: 0.663200
# Epoch 100, CIFAR-10 Batch 1:  Loss:     0.0513 Validation Accuracy: 0.658400
# Epoch 101, CIFAR-10 Batch 1:  Loss:     0.0509 Validation Accuracy: 0.659200
# Epoch 102, CIFAR-10 Batch 1:  Loss:     0.0379 Validation Accuracy: 0.662400
# Epoch 103, CIFAR-10 Batch 1:  Loss:     0.0439 Validation Accuracy: 0.662000
# Epoch 104, CIFAR-10 Batch 1:  Loss:     0.0576 Validation Accuracy: 0.658600
# Epoch 105, CIFAR-10 Batch 1:  Loss:     0.0233 Validation Accuracy: 0.679000
# Epoch 106, CIFAR-10 Batch 1:  Loss:     0.0360 Validation Accuracy: 0.662200
# Epoch 107, CIFAR-10 Batch 1:  Loss:     0.0459 Validation Accuracy: 0.656000
# Epoch 108, CIFAR-10 Batch 1:  Loss:     0.0350 Validation Accuracy: 0.685800
# Epoch 109, CIFAR-10 Batch 1:  Loss:     0.0334 Validation Accuracy: 0.658600
# Epoch 110, CIFAR-10 Batch 1:  Loss:     0.0219 Validation Accuracy: 0.681000
# Epoch 111, CIFAR-10 Batch 1:  Loss:     0.0478 Validation Accuracy: 0.665800
# Epoch 112, CIFAR-10 Batch 1:  Loss:     0.0309 Validation Accuracy: 0.677800
# Epoch 113, CIFAR-10 Batch 1:  Loss:     0.0406 Validation Accuracy: 0.660800
# Epoch 114, CIFAR-10 Batch 1:  Loss:     0.0532 Validation Accuracy: 0.667600
# Epoch 115, CIFAR-10 Batch 1:  Loss:     0.0421 Validation Accuracy: 0.668800
# Epoch 116, CIFAR-10 Batch 1:  Loss:     0.0229 Validation Accuracy: 0.670000
# Epoch 117, CIFAR-10 Batch 1:  Loss:     0.0268 Validation Accuracy: 0.678400
# Epoch 118, CIFAR-10 Batch 1:  Loss:     0.0153 Validation Accuracy: 0.677400
# Epoch 119, CIFAR-10 Batch 1:  Loss:     0.0355 Validation Accuracy: 0.674800
# Epoch 120, CIFAR-10 Batch 1:  Loss:     0.0162 Validation Accuracy: 0.671800
# Epoch 121, CIFAR-10 Batch 1:  Loss:     0.0156 Validation Accuracy: 0.671200
# Epoch 122, CIFAR-10 Batch 1:  Loss:     0.0157 Validation Accuracy: 0.673600
# Epoch 123, CIFAR-10 Batch 1:  Loss:     0.0196 Validation Accuracy: 0.661000
# Epoch 124, CIFAR-10 Batch 1:  Loss:     0.0266 Validation Accuracy: 0.664600
# Epoch 125, CIFAR-10 Batch 1:  Loss:     0.0169 Validation Accuracy: 0.672400
# Epoch 126, CIFAR-10 Batch 1:  Loss:     0.0167 Validation Accuracy: 0.659600
# Epoch 127, CIFAR-10 Batch 1:  Loss:     0.0122 Validation Accuracy: 0.667200
# Epoch 128, CIFAR-10 Batch 1:  Loss:     0.0246 Validation Accuracy: 0.676800
# Epoch 129, CIFAR-10 Batch 1:  Loss:     0.0089 Validation Accuracy: 0.678000
# Epoch 130, CIFAR-10 Batch 1:  Loss:     0.0091 Validation Accuracy: 0.675000
# Epoch 131, CIFAR-10 Batch 1:  Loss:     0.0083 Validation Accuracy: 0.678400
# Epoch 132, CIFAR-10 Batch 1:  Loss:     0.0101 Validation Accuracy: 0.671400
# Epoch 133, CIFAR-10 Batch 1:  Loss:     0.0055 Validation Accuracy: 0.677600
# Epoch 134, CIFAR-10 Batch 1:  Loss:     0.0172 Validation Accuracy: 0.668600
# Epoch 135, CIFAR-10 Batch 1:  Loss:     0.0056 Validation Accuracy: 0.665800
# Epoch 136, CIFAR-10 Batch 1:  Loss:     0.0069 Validation Accuracy: 0.670000
# Epoch 137, CIFAR-10 Batch 1:  Loss:     0.0031 Validation Accuracy: 0.685400
# Epoch 138, CIFAR-10 Batch 1:  Loss:     0.0119 Validation Accuracy: 0.665800
# Epoch 139, CIFAR-10 Batch 1:  Loss:     0.0151 Validation Accuracy: 0.673400
# Epoch 140, CIFAR-10 Batch 1:  Loss:     0.0065 Validation Accuracy: 0.671600
# Epoch 141, CIFAR-10 Batch 1:  Loss:     0.0052 Validation Accuracy: 0.671200
# Epoch 142, CIFAR-10 Batch 1:  Loss:     0.0046 Validation Accuracy: 0.684200
# Epoch 143, CIFAR-10 Batch 1:  Loss:     0.0060 Validation Accuracy: 0.685600
# Epoch 144, CIFAR-10 Batch 1:  Loss:     0.0040 Validation Accuracy: 0.684400
# Epoch 145, CIFAR-10 Batch 1:  Loss:     0.0035 Validation Accuracy: 0.675000
# Epoch 146, CIFAR-10 Batch 1:  Loss:     0.0200 Validation Accuracy: 0.682200
# Epoch 147, CIFAR-10 Batch 1:  Loss:     0.0044 Validation Accuracy: 0.677800
# Epoch 148, CIFAR-10 Batch 1:  Loss:     0.0072 Validation Accuracy: 0.673200
# Epoch 149, CIFAR-10 Batch 1:  Loss:     0.0042 Validation Accuracy: 0.687800
# Epoch 150, CIFAR-10 Batch 1:  Loss:     0.0064 Validation Accuracy: 0.681200
# Epoch 151, CIFAR-10 Batch 1:  Loss:     0.0097 Validation Accuracy: 0.683200
# Epoch 152, CIFAR-10 Batch 1:  Loss:     0.0029 Validation Accuracy: 0.682000
# Epoch 153, CIFAR-10 Batch 1:  Loss:     0.0022 Validation Accuracy: 0.683800
# Epoch 154, CIFAR-10 Batch 1:  Loss:     0.0021 Validation Accuracy: 0.694200
# Epoch 155, CIFAR-10 Batch 1:  Loss:     0.0027 Validation Accuracy: 0.684600
# Epoch 156, CIFAR-10 Batch 1:  Loss:     0.0020 Validation Accuracy: 0.673000
# Epoch 157, CIFAR-10 Batch 1:  Loss:     0.0063 Validation Accuracy: 0.683800
# Epoch 158, CIFAR-10 Batch 1:  Loss:     0.0075 Validation Accuracy: 0.684200
# Epoch 159, CIFAR-10 Batch 1:  Loss:     0.0029 Validation Accuracy: 0.684800
# Epoch 160, CIFAR-10 Batch 1:  Loss:     0.0015 Validation Accuracy: 0.685200
# Epoch 161, CIFAR-10 Batch 1:  Loss:     0.0043 Validation Accuracy: 0.685200
# Epoch 162, CIFAR-10 Batch 1:  Loss:     0.0071 Validation Accuracy: 0.665800
# Epoch 163, CIFAR-10 Batch 1:  Loss:     0.0029 Validation Accuracy: 0.690200
# Epoch 164, CIFAR-10 Batch 1:  Loss:     0.0045 Validation Accuracy: 0.680000
# Epoch 165, CIFAR-10 Batch 1:  Loss:     0.0046 Validation Accuracy: 0.672600
# Epoch 166, CIFAR-10 Batch 1:  Loss:     0.0022 Validation Accuracy: 0.684600
# Epoch 167, CIFAR-10 Batch 1:  Loss:     0.0012 Validation Accuracy: 0.681000
# Epoch 168, CIFAR-10 Batch 1:  Loss:     0.0008 Validation Accuracy: 0.686200
# Epoch 169, CIFAR-10 Batch 1:  Loss:     0.0061 Validation Accuracy: 0.672200
# Epoch 170, CIFAR-10 Batch 1:  Loss:     0.0029 Validation Accuracy: 0.688600
# Epoch 171, CIFAR-10 Batch 1:  Loss:     0.0021 Validation Accuracy: 0.677200
# Epoch 172, CIFAR-10 Batch 1:  Loss:     0.0058 Validation Accuracy: 0.682400
# Epoch 173, CIFAR-10 Batch 1:  Loss:     0.0020 Validation Accuracy: 0.694600
# Epoch 174, CIFAR-10 Batch 1:  Loss:     0.0010 Validation Accuracy: 0.688400
# Epoch 175, CIFAR-10 Batch 1:  Loss:     0.0035 Validation Accuracy: 0.682800
# Epoch 176, CIFAR-10 Batch 1:  Loss:     0.0011 Validation Accuracy: 0.688000
# Epoch 177, CIFAR-10 Batch 1:  Loss:     0.0021 Validation Accuracy: 0.689600
# Epoch 178, CIFAR-10 Batch 1:  Loss:     0.0006 Validation Accuracy: 0.688400
# Epoch 179, CIFAR-10 Batch 1:  Loss:     0.0005 Validation Accuracy: 0.674800
# Epoch 180, CIFAR-10 Batch 1:  Loss:     0.0068 Validation Accuracy: 0.676600
# Epoch 181, CIFAR-10 Batch 1:  Loss:     0.0023 Validation Accuracy: 0.681200
# Epoch 182, CIFAR-10 Batch 1:  Loss:     0.0011 Validation Accuracy: 0.676000
# Epoch 183, CIFAR-10 Batch 1:  Loss:     0.0059 Validation Accuracy: 0.675200
# Epoch 184, CIFAR-10 Batch 1:  Loss:     0.0007 Validation Accuracy: 0.683000
# Epoch 185, CIFAR-10 Batch 1:  Loss:     0.0004 Validation Accuracy: 0.684200
# Epoch 186, CIFAR-10 Batch 1:  Loss:     0.0018 Validation Accuracy: 0.683200
# Epoch 187, CIFAR-10 Batch 1:  Loss:     0.0011 Validation Accuracy: 0.673800
# Epoch 188, CIFAR-10 Batch 1:  Loss:     0.0005 Validation Accuracy: 0.687600
# Epoch 189, CIFAR-10 Batch 1:  Loss:     0.0005 Validation Accuracy: 0.686000
# Epoch 190, CIFAR-10 Batch 1:  Loss:     0.0005 Validation Accuracy: 0.687400
# Epoch 191, CIFAR-10 Batch 1:  Loss:     0.0008 Validation Accuracy: 0.689600
# Epoch 192, CIFAR-10 Batch 1:  Loss:     0.0002 Validation Accuracy: 0.684400
# Epoch 193, CIFAR-10 Batch 1:  Loss:     0.0002 Validation Accuracy: 0.688600
# Epoch 194, CIFAR-10 Batch 1:  Loss:     0.0053 Validation Accuracy: 0.684600
# Epoch 195, CIFAR-10 Batch 1:  Loss:     0.0002 Validation Accuracy: 0.686800
# Epoch 196, CIFAR-10 Batch 1:  Loss:     0.0004 Validation Accuracy: 0.675400
# Epoch 197, CIFAR-10 Batch 1:  Loss:     0.0050 Validation Accuracy: 0.679000
# Epoch 198, CIFAR-10 Batch 1:  Loss:     0.0002 Validation Accuracy: 0.691400
# Epoch 199, CIFAR-10 Batch 1:  Loss:     0.0015 Validation Accuracy: 0.686400
# Epoch 200, CIFAR-10 Batch 1:  Loss:     0.0006 Validation Accuracy: 0.681600

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.3046 Validation Accuracy: 0.095800
# Epoch  1, CIFAR-10 Batch 2:  Loss:     2.3025 Validation Accuracy: 0.097400
# Epoch  1, CIFAR-10 Batch 3:  Loss:     2.2833 Validation Accuracy: 0.148200
# Epoch  1, CIFAR-10 Batch 4:  Loss:     2.2252 Validation Accuracy: 0.161000
# Epoch  1, CIFAR-10 Batch 5:  Loss:     2.1382 Validation Accuracy: 0.232400
# Epoch  2, CIFAR-10 Batch 1:  Loss:     2.0543 Validation Accuracy: 0.258400
# Epoch  2, CIFAR-10 Batch 2:  Loss:     1.9620 Validation Accuracy: 0.296600
# Epoch  2, CIFAR-10 Batch 3:  Loss:     1.8148 Validation Accuracy: 0.299000
# Epoch  2, CIFAR-10 Batch 4:  Loss:     1.8066 Validation Accuracy: 0.331200
# Epoch  2, CIFAR-10 Batch 5:  Loss:     1.7726 Validation Accuracy: 0.327000
# Epoch  3, CIFAR-10 Batch 1:  Loss:     1.7995 Validation Accuracy: 0.388400
# Epoch  3, CIFAR-10 Batch 2:  Loss:     1.7182 Validation Accuracy: 0.384800
# Epoch  3, CIFAR-10 Batch 3:  Loss:     1.5542 Validation Accuracy: 0.407400
# Epoch  3, CIFAR-10 Batch 4:  Loss:     1.6320 Validation Accuracy: 0.385600
# Epoch  3, CIFAR-10 Batch 5:  Loss:     1.5450 Validation Accuracy: 0.411800
# Epoch  4, CIFAR-10 Batch 1:  Loss:     1.6016 Validation Accuracy: 0.444600
# Epoch  4, CIFAR-10 Batch 2:  Loss:     1.5283 Validation Accuracy: 0.457800
# Epoch  4, CIFAR-10 Batch 3:  Loss:     1.4786 Validation Accuracy: 0.446200
# Epoch  4, CIFAR-10 Batch 4:  Loss:     1.4761 Validation Accuracy: 0.471600
# Epoch  4, CIFAR-10 Batch 5:  Loss:     1.3678 Validation Accuracy: 0.492000
# Epoch  5, CIFAR-10 Batch 1:  Loss:     1.5288 Validation Accuracy: 0.494800
# Epoch  5, CIFAR-10 Batch 2:  Loss:     1.4587 Validation Accuracy: 0.488400
# Epoch  5, CIFAR-10 Batch 3:  Loss:     1.3026 Validation Accuracy: 0.513000
# Epoch  5, CIFAR-10 Batch 4:  Loss:     1.3512 Validation Accuracy: 0.500600
# Epoch  5, CIFAR-10 Batch 5:  Loss:     1.3136 Validation Accuracy: 0.504400
# Epoch  6, CIFAR-10 Batch 1:  Loss:     1.4146 Validation Accuracy: 0.521600
# Epoch  6, CIFAR-10 Batch 2:  Loss:     1.3410 Validation Accuracy: 0.522400
# Epoch  6, CIFAR-10 Batch 3:  Loss:     1.2670 Validation Accuracy: 0.510600
# Epoch  6, CIFAR-10 Batch 4:  Loss:     1.2402 Validation Accuracy: 0.542200
# Epoch  6, CIFAR-10 Batch 5:  Loss:     1.2120 Validation Accuracy: 0.536200
# Epoch  7, CIFAR-10 Batch 1:  Loss:     1.3311 Validation Accuracy: 0.549400
# Epoch  7, CIFAR-10 Batch 2:  Loss:     1.2638 Validation Accuracy: 0.522200
# Epoch  7, CIFAR-10 Batch 3:  Loss:     1.1021 Validation Accuracy: 0.559600
# Epoch  7, CIFAR-10 Batch 4:  Loss:     1.1800 Validation Accuracy: 0.574800
# Epoch  7, CIFAR-10 Batch 5:  Loss:     1.1053 Validation Accuracy: 0.588600
# Epoch  8, CIFAR-10 Batch 1:  Loss:     1.2023 Validation Accuracy: 0.589600
# Epoch  8, CIFAR-10 Batch 2:  Loss:     1.1462 Validation Accuracy: 0.577200
# Epoch  8, CIFAR-10 Batch 3:  Loss:     1.0746 Validation Accuracy: 0.569200
# Epoch  8, CIFAR-10 Batch 4:  Loss:     1.1267 Validation Accuracy: 0.579400
# Epoch  8, CIFAR-10 Batch 5:  Loss:     1.0857 Validation Accuracy: 0.589800
# Epoch  9, CIFAR-10 Batch 1:  Loss:     1.1844 Validation Accuracy: 0.592800
# Epoch  9, CIFAR-10 Batch 2:  Loss:     1.0936 Validation Accuracy: 0.599800
# Epoch  9, CIFAR-10 Batch 3:  Loss:     1.0344 Validation Accuracy: 0.584600
# Epoch  9, CIFAR-10 Batch 4:  Loss:     1.0846 Validation Accuracy: 0.589400
# Epoch  9, CIFAR-10 Batch 5:  Loss:     0.9620 Validation Accuracy: 0.625800
# Epoch 10, CIFAR-10 Batch 1:  Loss:     1.1666 Validation Accuracy: 0.597000
# Epoch 10, CIFAR-10 Batch 2:  Loss:     1.0467 Validation Accuracy: 0.621600
# Epoch 10, CIFAR-10 Batch 3:  Loss:     0.9240 Validation Accuracy: 0.629000
# Epoch 10, CIFAR-10 Batch 4:  Loss:     0.9616 Validation Accuracy: 0.627800
# Epoch 10, CIFAR-10 Batch 5:  Loss:     0.9173 Validation Accuracy: 0.636200
# Epoch 11, CIFAR-10 Batch 1:  Loss:     0.9787 Validation Accuracy: 0.642600
# Epoch 11, CIFAR-10 Batch 2:  Loss:     0.9408 Validation Accuracy: 0.626200
# Epoch 11, CIFAR-10 Batch 3:  Loss:     0.8488 Validation Accuracy: 0.654000
# Epoch 11, CIFAR-10 Batch 4:  Loss:     0.8668 Validation Accuracy: 0.656400
# Epoch 11, CIFAR-10 Batch 5:  Loss:     0.8342 Validation Accuracy: 0.661600
# Epoch 12, CIFAR-10 Batch 1:  Loss:     0.9324 Validation Accuracy: 0.678000
# Epoch 12, CIFAR-10 Batch 2:  Loss:     0.9258 Validation Accuracy: 0.644600
# Epoch 12, CIFAR-10 Batch 3:  Loss:     0.8656 Validation Accuracy: 0.650800
# Epoch 12, CIFAR-10 Batch 4:  Loss:     0.8894 Validation Accuracy: 0.657800
# Epoch 12, CIFAR-10 Batch 5:  Loss:     0.7987 Validation Accuracy: 0.670800
# Epoch 13, CIFAR-10 Batch 1:  Loss:     0.9751 Validation Accuracy: 0.652800
# Epoch 13, CIFAR-10 Batch 2:  Loss:     0.9141 Validation Accuracy: 0.659800
# Epoch 13, CIFAR-10 Batch 3:  Loss:     0.8160 Validation Accuracy: 0.669600
# Epoch 13, CIFAR-10 Batch 4:  Loss:     0.8052 Validation Accuracy: 0.669800
# Epoch 13, CIFAR-10 Batch 5:  Loss:     0.7540 Validation Accuracy: 0.689400
# Epoch 14, CIFAR-10 Batch 1:  Loss:     0.9567 Validation Accuracy: 0.660200
# Epoch 14, CIFAR-10 Batch 2:  Loss:     0.8286 Validation Accuracy: 0.681400
# Epoch 14, CIFAR-10 Batch 3:  Loss:     0.7119 Validation Accuracy: 0.699000
# Epoch 14, CIFAR-10 Batch 4:  Loss:     0.7249 Validation Accuracy: 0.700400
# Epoch 14, CIFAR-10 Batch 5:  Loss:     0.7040 Validation Accuracy: 0.681600
# Epoch 15, CIFAR-10 Batch 1:  Loss:     0.9059 Validation Accuracy: 0.667800
# Epoch 15, CIFAR-10 Batch 2:  Loss:     0.7388 Validation Accuracy: 0.708000
# Epoch 15, CIFAR-10 Batch 3:  Loss:     0.6825 Validation Accuracy: 0.699800
# Epoch 15, CIFAR-10 Batch 4:  Loss:     0.7079 Validation Accuracy: 0.685800
# Epoch 15, CIFAR-10 Batch 5:  Loss:     0.7015 Validation Accuracy: 0.698800
# Epoch 16, CIFAR-10 Batch 1:  Loss:     0.8399 Validation Accuracy: 0.710600
# Epoch 16, CIFAR-10 Batch 2:  Loss:     0.7356 Validation Accuracy: 0.687200
# Epoch 16, CIFAR-10 Batch 3:  Loss:     0.6309 Validation Accuracy: 0.701400
# Epoch 16, CIFAR-10 Batch 4:  Loss:     0.7315 Validation Accuracy: 0.697200
# Epoch 16, CIFAR-10 Batch 5:  Loss:     0.6689 Validation Accuracy: 0.700400
# Epoch 17, CIFAR-10 Batch 1:  Loss:     0.8572 Validation Accuracy: 0.716400
# Epoch 17, CIFAR-10 Batch 2:  Loss:     0.7161 Validation Accuracy: 0.701200
# Epoch 17, CIFAR-10 Batch 3:  Loss:     0.5801 Validation Accuracy: 0.720400
# Epoch 17, CIFAR-10 Batch 4:  Loss:     0.6704 Validation Accuracy: 0.709200
# Epoch 17, CIFAR-10 Batch 5:  Loss:     0.6206 Validation Accuracy: 0.728200
# Epoch 18, CIFAR-10 Batch 1:  Loss:     0.8581 Validation Accuracy: 0.692800
# Epoch 18, CIFAR-10 Batch 2:  Loss:     0.6637 Validation Accuracy: 0.726000
# Epoch 18, CIFAR-10 Batch 3:  Loss:     0.5319 Validation Accuracy: 0.726200
# Epoch 18, CIFAR-10 Batch 4:  Loss:     0.6266 Validation Accuracy: 0.729600
# Epoch 18, CIFAR-10 Batch 5:  Loss:     0.5859 Validation Accuracy: 0.721000
# Epoch 19, CIFAR-10 Batch 1:  Loss:     0.7884 Validation Accuracy: 0.716400
# Epoch 19, CIFAR-10 Batch 2:  Loss:     0.6666 Validation Accuracy: 0.720400
# Epoch 19, CIFAR-10 Batch 3:  Loss:     0.5143 Validation Accuracy: 0.724400
# Epoch 19, CIFAR-10 Batch 4:  Loss:     0.6777 Validation Accuracy: 0.715600
# Epoch 19, CIFAR-10 Batch 5:  Loss:     0.5963 Validation Accuracy: 0.731400
# Epoch 20, CIFAR-10 Batch 1:  Loss:     0.7905 Validation Accuracy: 0.713000
# Epoch 20, CIFAR-10 Batch 2:  Loss:     0.6892 Validation Accuracy: 0.717400
# Epoch 20, CIFAR-10 Batch 3:  Loss:     0.4715 Validation Accuracy: 0.747000
# Epoch 20, CIFAR-10 Batch 4:  Loss:     0.6013 Validation Accuracy: 0.721600
# Epoch 20, CIFAR-10 Batch 5:  Loss:     0.5361 Validation Accuracy: 0.721400
# Epoch 21, CIFAR-10 Batch 1:  Loss:     0.7489 Validation Accuracy: 0.712200
# Epoch 21, CIFAR-10 Batch 2:  Loss:     0.6285 Validation Accuracy: 0.727400
# Epoch 21, CIFAR-10 Batch 3:  Loss:     0.5230 Validation Accuracy: 0.735000
# Epoch 21, CIFAR-10 Batch 4:  Loss:     0.5857 Validation Accuracy: 0.733800
# Epoch 21, CIFAR-10 Batch 5:  Loss:     0.5152 Validation Accuracy: 0.727800
# Epoch 22, CIFAR-10 Batch 1:  Loss:     0.6680 Validation Accuracy: 0.742600
# Epoch 22, CIFAR-10 Batch 2:  Loss:     0.6019 Validation Accuracy: 0.730600
# Epoch 22, CIFAR-10 Batch 3:  Loss:     0.4263 Validation Accuracy: 0.745400
# Epoch 22, CIFAR-10 Batch 4:  Loss:     0.5036 Validation Accuracy: 0.746800
# Epoch 22, CIFAR-10 Batch 5:  Loss:     0.4542 Validation Accuracy: 0.745800
# Epoch 23, CIFAR-10 Batch 1:  Loss:     0.7132 Validation Accuracy: 0.742400
# Epoch 23, CIFAR-10 Batch 2:  Loss:     0.5547 Validation Accuracy: 0.748400
# Epoch 23, CIFAR-10 Batch 3:  Loss:     0.3850 Validation Accuracy: 0.749800
# Epoch 23, CIFAR-10 Batch 4:  Loss:     0.4940 Validation Accuracy: 0.743000
# Epoch 23, CIFAR-10 Batch 5:  Loss:     0.4438 Validation Accuracy: 0.758400
# Epoch 24, CIFAR-10 Batch 1:  Loss:     0.5864 Validation Accuracy: 0.748600
# Epoch 24, CIFAR-10 Batch 2:  Loss:     0.5508 Validation Accuracy: 0.757600
# Epoch 24, CIFAR-10 Batch 3:  Loss:     0.4295 Validation Accuracy: 0.743600
# Epoch 24, CIFAR-10 Batch 4:  Loss:     0.4915 Validation Accuracy: 0.747800
# Epoch 24, CIFAR-10 Batch 5:  Loss:     0.4451 Validation Accuracy: 0.729000
# Epoch 25, CIFAR-10 Batch 1:  Loss:     0.6484 Validation Accuracy: 0.734600
# Epoch 25, CIFAR-10 Batch 2:  Loss:     0.5354 Validation Accuracy: 0.753000
# Epoch 25, CIFAR-10 Batch 3:  Loss:     0.3886 Validation Accuracy: 0.746000
# Epoch 25, CIFAR-10 Batch 4:  Loss:     0.4580 Validation Accuracy: 0.756800
# Epoch 25, CIFAR-10 Batch 5:  Loss:     0.4017 Validation Accuracy: 0.745200
# Epoch 26, CIFAR-10 Batch 1:  Loss:     0.5994 Validation Accuracy: 0.740800
# Epoch 26, CIFAR-10 Batch 2:  Loss:     0.4980 Validation Accuracy: 0.763400
# Epoch 26, CIFAR-10 Batch 3:  Loss:     0.3962 Validation Accuracy: 0.750400
# Epoch 26, CIFAR-10 Batch 4:  Loss:     0.3875 Validation Accuracy: 0.764000
# Epoch 26, CIFAR-10 Batch 5:  Loss:     0.3858 Validation Accuracy: 0.764200
# Epoch 27, CIFAR-10 Batch 1:  Loss:     0.4709 Validation Accuracy: 0.760200
# Epoch 27, CIFAR-10 Batch 2:  Loss:     0.4882 Validation Accuracy: 0.755000
# Epoch 27, CIFAR-10 Batch 3:  Loss:     0.3187 Validation Accuracy: 0.767600
# Epoch 27, CIFAR-10 Batch 4:  Loss:     0.4042 Validation Accuracy: 0.760600
# Epoch 27, CIFAR-10 Batch 5:  Loss:     0.3643 Validation Accuracy: 0.762400
# Epoch 28, CIFAR-10 Batch 1:  Loss:     0.5198 Validation Accuracy: 0.751400
# Epoch 28, CIFAR-10 Batch 2:  Loss:     0.4590 Validation Accuracy: 0.765200
# Epoch 28, CIFAR-10 Batch 3:  Loss:     0.3239 Validation Accuracy: 0.770200
# Epoch 28, CIFAR-10 Batch 4:  Loss:     0.4163 Validation Accuracy: 0.760000
# Epoch 28, CIFAR-10 Batch 5:  Loss:     0.3316 Validation Accuracy: 0.767000
# Epoch 29, CIFAR-10 Batch 1:  Loss:     0.4837 Validation Accuracy: 0.758400
# Epoch 29, CIFAR-10 Batch 2:  Loss:     0.4408 Validation Accuracy: 0.759400
# Epoch 29, CIFAR-10 Batch 3:  Loss:     0.3283 Validation Accuracy: 0.758400
# Epoch 29, CIFAR-10 Batch 4:  Loss:     0.3624 Validation Accuracy: 0.769400
# Epoch 29, CIFAR-10 Batch 5:  Loss:     0.3169 Validation Accuracy: 0.770600
# Epoch 30, CIFAR-10 Batch 1:  Loss:     0.4446 Validation Accuracy: 0.765000
# Epoch 30, CIFAR-10 Batch 2:  Loss:     0.5057 Validation Accuracy: 0.741600
# Epoch 30, CIFAR-10 Batch 3:  Loss:     0.2867 Validation Accuracy: 0.768800
# Epoch 30, CIFAR-10 Batch 4:  Loss:     0.3516 Validation Accuracy: 0.775800
# Epoch 30, CIFAR-10 Batch 5:  Loss:     0.3288 Validation Accuracy: 0.762200
# Epoch 31, CIFAR-10 Batch 1:  Loss:     0.4464 Validation Accuracy: 0.769600
# Epoch 31, CIFAR-10 Batch 2:  Loss:     0.4638 Validation Accuracy: 0.751200
# Epoch 31, CIFAR-10 Batch 3:  Loss:     0.2810 Validation Accuracy: 0.765400
# Epoch 31, CIFAR-10 Batch 4:  Loss:     0.3259 Validation Accuracy: 0.776200
# Epoch 31, CIFAR-10 Batch 5:  Loss:     0.3570 Validation Accuracy: 0.760400
# Epoch 32, CIFAR-10 Batch 1:  Loss:     0.4907 Validation Accuracy: 0.766000
# Epoch 32, CIFAR-10 Batch 2:  Loss:     0.4292 Validation Accuracy: 0.750600
# Epoch 32, CIFAR-10 Batch 3:  Loss:     0.2753 Validation Accuracy: 0.766400
# Epoch 32, CIFAR-10 Batch 4:  Loss:     0.3757 Validation Accuracy: 0.763800
# Epoch 32, CIFAR-10 Batch 5:  Loss:     0.3058 Validation Accuracy: 0.775800
# Epoch 33, CIFAR-10 Batch 1:  Loss:     0.4061 Validation Accuracy: 0.766600
# Epoch 33, CIFAR-10 Batch 2:  Loss:     0.4121 Validation Accuracy: 0.764600
# Epoch 33, CIFAR-10 Batch 3:  Loss:     0.2769 Validation Accuracy: 0.773200
# Epoch 33, CIFAR-10 Batch 4:  Loss:     0.3528 Validation Accuracy: 0.773400
# Epoch 33, CIFAR-10 Batch 5:  Loss:     0.2838 Validation Accuracy: 0.783000
# Epoch 34, CIFAR-10 Batch 1:  Loss:     0.3887 Validation Accuracy: 0.765600
# Epoch 34, CIFAR-10 Batch 2:  Loss:     0.3742 Validation Accuracy: 0.769400
# Epoch 34, CIFAR-10 Batch 3:  Loss:     0.2604 Validation Accuracy: 0.778600
# Epoch 34, CIFAR-10 Batch 4:  Loss:     0.2871 Validation Accuracy: 0.784400
# Epoch 34, CIFAR-10 Batch 5:  Loss:     0.3051 Validation Accuracy: 0.772200
# Epoch 35, CIFAR-10 Batch 1:  Loss:     0.4091 Validation Accuracy: 0.770000
# Epoch 35, CIFAR-10 Batch 2:  Loss:     0.4118 Validation Accuracy: 0.751400
# Epoch 35, CIFAR-10 Batch 3:  Loss:     0.2907 Validation Accuracy: 0.764800
# Epoch 35, CIFAR-10 Batch 4:  Loss:     0.3606 Validation Accuracy: 0.779200
# Epoch 35, CIFAR-10 Batch 5:  Loss:     0.3016 Validation Accuracy: 0.762600
# Epoch 36, CIFAR-10 Batch 1:  Loss:     0.3774 Validation Accuracy: 0.776800
# Epoch 36, CIFAR-10 Batch 2:  Loss:     0.4128 Validation Accuracy: 0.758600
# Epoch 36, CIFAR-10 Batch 3:  Loss:     0.2759 Validation Accuracy: 0.772400
# Epoch 36, CIFAR-10 Batch 4:  Loss:     0.3247 Validation Accuracy: 0.772800
# Epoch 36, CIFAR-10 Batch 5:  Loss:     0.2659 Validation Accuracy: 0.777200
# Epoch 37, CIFAR-10 Batch 1:  Loss:     0.3590 Validation Accuracy: 0.775200
# Epoch 37, CIFAR-10 Batch 2:  Loss:     0.3496 Validation Accuracy: 0.780200
# Epoch 37, CIFAR-10 Batch 3:  Loss:     0.2584 Validation Accuracy: 0.773800
# Epoch 37, CIFAR-10 Batch 4:  Loss:     0.2974 Validation Accuracy: 0.775600
# Epoch 37, CIFAR-10 Batch 5:  Loss:     0.2525 Validation Accuracy: 0.778800
# Epoch 38, CIFAR-10 Batch 1:  Loss:     0.3229 Validation Accuracy: 0.780000
# Epoch 38, CIFAR-10 Batch 2:  Loss:     0.3877 Validation Accuracy: 0.771400
# Epoch 38, CIFAR-10 Batch 3:  Loss:     0.2156 Validation Accuracy: 0.788800
# Epoch 38, CIFAR-10 Batch 4:  Loss:     0.3084 Validation Accuracy: 0.776600
# Epoch 38, CIFAR-10 Batch 5:  Loss:     0.2509 Validation Accuracy: 0.771600
# Epoch 39, CIFAR-10 Batch 1:  Loss:     0.3199 Validation Accuracy: 0.779200
# Epoch 39, CIFAR-10 Batch 2:  Loss:     0.3137 Validation Accuracy: 0.783000
# Epoch 39, CIFAR-10 Batch 3:  Loss:     0.2418 Validation Accuracy: 0.787800
# Epoch 39, CIFAR-10 Batch 4:  Loss:     0.3100 Validation Accuracy: 0.762600
# Epoch 39, CIFAR-10 Batch 5:  Loss:     0.2721 Validation Accuracy: 0.769600
# Epoch 40, CIFAR-10 Batch 1:  Loss:     0.3237 Validation Accuracy: 0.774200
# Epoch 40, CIFAR-10 Batch 2:  Loss:     0.3374 Validation Accuracy: 0.764000
# Epoch 40, CIFAR-10 Batch 3:  Loss:     0.2320 Validation Accuracy: 0.780000
# Epoch 40, CIFAR-10 Batch 4:  Loss:     0.2835 Validation Accuracy: 0.776400
# Epoch 40, CIFAR-10 Batch 5:  Loss:     0.2441 Validation Accuracy: 0.779000
# Epoch 41, CIFAR-10 Batch 1:  Loss:     0.2850 Validation Accuracy: 0.786800
# Epoch 41, CIFAR-10 Batch 2:  Loss:     0.3162 Validation Accuracy: 0.768000
# Epoch 41, CIFAR-10 Batch 3:  Loss:     0.2192 Validation Accuracy: 0.783800
# Epoch 41, CIFAR-10 Batch 4:  Loss:     0.2698 Validation Accuracy: 0.783200
# Epoch 41, CIFAR-10 Batch 5:  Loss:     0.2413 Validation Accuracy: 0.778000
# Epoch 42, CIFAR-10 Batch 1:  Loss:     0.2753 Validation Accuracy: 0.781600
# Epoch 42, CIFAR-10 Batch 2:  Loss:     0.2648 Validation Accuracy: 0.778200
# Epoch 42, CIFAR-10 Batch 3:  Loss:     0.2001 Validation Accuracy: 0.786200
# Epoch 42, CIFAR-10 Batch 4:  Loss:     0.3065 Validation Accuracy: 0.777600
# Epoch 42, CIFAR-10 Batch 5:  Loss:     0.2989 Validation Accuracy: 0.758800
# Epoch 43, CIFAR-10 Batch 1:  Loss:     0.2698 Validation Accuracy: 0.782800
# Epoch 43, CIFAR-10 Batch 2:  Loss:     0.2594 Validation Accuracy: 0.784800
# Epoch 43, CIFAR-10 Batch 3:  Loss:     0.1829 Validation Accuracy: 0.793200
# Epoch 43, CIFAR-10 Batch 4:  Loss:     0.2327 Validation Accuracy: 0.785800
# Epoch 43, CIFAR-10 Batch 5:  Loss:     0.2312 Validation Accuracy: 0.769400
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.2564 Validation Accuracy: 0.779400
# Epoch 44, CIFAR-10 Batch 2:  Loss:     0.3025 Validation Accuracy: 0.771000
# Epoch 44, CIFAR-10 Batch 3:  Loss:     0.1739 Validation Accuracy: 0.789400
# Epoch 44, CIFAR-10 Batch 4:  Loss:     0.2545 Validation Accuracy: 0.777200
# Epoch 44, CIFAR-10 Batch 5:  Loss:     0.2128 Validation Accuracy: 0.783200
# Epoch 45, CIFAR-10 Batch 1:  Loss:     0.2945 Validation Accuracy: 0.781600
# Epoch 45, CIFAR-10 Batch 2:  Loss:     0.2426 Validation Accuracy: 0.788200
# Epoch 45, CIFAR-10 Batch 3:  Loss:     0.2058 Validation Accuracy: 0.780200
# Epoch 45, CIFAR-10 Batch 4:  Loss:     0.2341 Validation Accuracy: 0.784600
# Epoch 45, CIFAR-10 Batch 5:  Loss:     0.2147 Validation Accuracy: 0.770800
# Epoch 46, CIFAR-10 Batch 1:  Loss:     0.2586 Validation Accuracy: 0.783400
# Epoch 46, CIFAR-10 Batch 2:  Loss:     0.2557 Validation Accuracy: 0.778600
# Epoch 46, CIFAR-10 Batch 3:  Loss:     0.1718 Validation Accuracy: 0.776600
# Epoch 46, CIFAR-10 Batch 4:  Loss:     0.2199 Validation Accuracy: 0.785600
# Epoch 46, CIFAR-10 Batch 5:  Loss:     0.1785 Validation Accuracy: 0.783200
# Epoch 47, CIFAR-10 Batch 1:  Loss:     0.2312 Validation Accuracy: 0.781000
# Epoch 47, CIFAR-10 Batch 2:  Loss:     0.2604 Validation Accuracy: 0.771200
# Epoch 47, CIFAR-10 Batch 3:  Loss:     0.2360 Validation Accuracy: 0.785000
# Epoch 47, CIFAR-10 Batch 4:  Loss:     0.2205 Validation Accuracy: 0.788200
# Epoch 47, CIFAR-10 Batch 5:  Loss:     0.1631 Validation Accuracy: 0.794200
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.2114 Validation Accuracy: 0.793800
# Epoch 48, CIFAR-10 Batch 2:  Loss:     0.3110 Validation Accuracy: 0.779400
# Epoch 48, CIFAR-10 Batch 3:  Loss:     0.1917 Validation Accuracy: 0.780400
# Epoch 48, CIFAR-10 Batch 4:  Loss:     0.2289 Validation Accuracy: 0.792200
# Epoch 48, CIFAR-10 Batch 5:  Loss:     0.1572 Validation Accuracy: 0.790400
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.2585 Validation Accuracy: 0.785600
# Epoch 49, CIFAR-10 Batch 2:  Loss:     0.2128 Validation Accuracy: 0.783600
# Epoch 49, CIFAR-10 Batch 3:  Loss:     0.1616 Validation Accuracy: 0.793200
# Epoch 49, CIFAR-10 Batch 4:  Loss:     0.1665 Validation Accuracy: 0.798000
# Epoch 49, CIFAR-10 Batch 5:  Loss:     0.1437 Validation Accuracy: 0.795000
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.2165 Validation Accuracy: 0.778600
# Epoch 50, CIFAR-10 Batch 2:  Loss:     0.1895 Validation Accuracy: 0.794000
# Epoch 50, CIFAR-10 Batch 3:  Loss:     0.1532 Validation Accuracy: 0.794200
# Epoch 50, CIFAR-10 Batch 4:  Loss:     0.1842 Validation Accuracy: 0.795000
# Epoch 50, CIFAR-10 Batch 5:  Loss:     0.1514 Validation Accuracy: 0.787800
# Epoch 51, CIFAR-10 Batch 1:  Loss:     0.2177 Validation Accuracy: 0.797800
# Epoch 51, CIFAR-10 Batch 2:  Loss:     0.2265 Validation Accuracy: 0.780000
# Epoch 51, CIFAR-10 Batch 3:  Loss:     0.1693 Validation Accuracy: 0.782200
# Epoch 51, CIFAR-10 Batch 4:  Loss:     0.1820 Validation Accuracy: 0.797400
# Epoch 51, CIFAR-10 Batch 5:  Loss:     0.1548 Validation Accuracy: 0.787400
# Epoch 52, CIFAR-10 Batch 1:  Loss:     0.2252 Validation Accuracy: 0.793600
# Epoch 52, CIFAR-10 Batch 2:  Loss:     0.2097 Validation Accuracy: 0.774000
# Epoch 52, CIFAR-10 Batch 3:  Loss:     0.1377 Validation Accuracy: 0.793800
# Epoch 52, CIFAR-10 Batch 4:  Loss:     0.1735 Validation Accuracy: 0.791000
# Epoch 52, CIFAR-10 Batch 5:  Loss:     0.1538 Validation Accuracy: 0.790200
# Epoch 53, CIFAR-10 Batch 1:  Loss:     0.2311 Validation Accuracy: 0.784400
# Epoch 53, CIFAR-10 Batch 2:  Loss:     0.2093 Validation Accuracy: 0.788000
# Epoch 53, CIFAR-10 Batch 3:  Loss:     0.1416 Validation Accuracy: 0.794600
# Epoch 53, CIFAR-10 Batch 4:  Loss:     0.1681 Validation Accuracy: 0.804000
# Epoch 53, CIFAR-10 Batch 5:  Loss:     0.1009 Validation Accuracy: 0.793800
# Epoch 54, CIFAR-10 Batch 1:  Loss:     0.2486 Validation Accuracy: 0.789400
# Epoch 54, CIFAR-10 Batch 2:  Loss:     0.1713 Validation Accuracy: 0.794200
# Epoch 54, CIFAR-10 Batch 3:  Loss:     0.1285 Validation Accuracy: 0.794800
# Epoch 54, CIFAR-10 Batch 4:  Loss:     0.1922 Validation Accuracy: 0.786800
# Epoch 54, CIFAR-10 Batch 5:  Loss:     0.1406 Validation Accuracy: 0.793600
# Epoch 55, CIFAR-10 Batch 1:  Loss:     0.2281 Validation Accuracy: 0.790200
# Epoch 55, CIFAR-10 Batch 2:  Loss:     0.1893 Validation Accuracy: 0.784200
# Epoch 55, CIFAR-10 Batch 3:  Loss:     0.1644 Validation Accuracy: 0.785600
# Epoch 55, CIFAR-10 Batch 4:  Loss:     0.1811 Validation Accuracy: 0.787200
# Epoch 55, CIFAR-10 Batch 5:  Loss:     0.1552 Validation Accuracy: 0.790800
# Epoch 56, CIFAR-10 Batch 1:  Loss:     0.2270 Validation Accuracy: 0.779600
# Epoch 56, CIFAR-10 Batch 2:  Loss:     0.1815 Validation Accuracy: 0.793800
# Epoch 56, CIFAR-10 Batch 3:  Loss:     0.1089 Validation Accuracy: 0.783600
# Epoch 56, CIFAR-10 Batch 4:  Loss:     0.1624 Validation Accuracy: 0.788400
# Epoch 56, CIFAR-10 Batch 5:  Loss:     0.1033 Validation Accuracy: 0.794000
# Epoch 57, CIFAR-10 Batch 1:  Loss:     0.1566 Validation Accuracy: 0.797200
# Epoch 57, CIFAR-10 Batch 2:  Loss:     0.1529 Validation Accuracy: 0.789600
# Epoch 57, CIFAR-10 Batch 3:  Loss:     0.0899 Validation Accuracy: 0.790800
# Epoch 57, CIFAR-10 Batch 4:  Loss:     0.1480 Validation Accuracy: 0.789800
# Epoch 57, CIFAR-10 Batch 5:  Loss:     0.0905 Validation Accuracy: 0.801400
# Epoch 58, CIFAR-10 Batch 1:  Loss:     0.1708 Validation Accuracy: 0.792400
# Epoch 58, CIFAR-10 Batch 2:  Loss:     0.1433 Validation Accuracy: 0.794200
# Epoch 58, CIFAR-10 Batch 3:  Loss:     0.1054 Validation Accuracy: 0.797400
# Epoch 58, CIFAR-10 Batch 4:  Loss:     0.1365 Validation Accuracy: 0.797400
# Epoch 58, CIFAR-10 Batch 5:  Loss:     0.1342 Validation Accuracy: 0.789200
# Epoch 59, CIFAR-10 Batch 1:  Loss:     0.1796 Validation Accuracy: 0.791600
# Epoch 59, CIFAR-10 Batch 2:  Loss:     0.1612 Validation Accuracy: 0.794600
# Epoch 59, CIFAR-10 Batch 3:  Loss:     0.1203 Validation Accuracy: 0.789600
# Epoch 59, CIFAR-10 Batch 4:  Loss:     0.1406 Validation Accuracy: 0.798800
# Epoch 59, CIFAR-10 Batch 5:  Loss:     0.1159 Validation Accuracy: 0.784400
# Epoch 60, CIFAR-10 Batch 1:  Loss:     0.1738 Validation Accuracy: 0.797400
# Epoch 60, CIFAR-10 Batch 2:  Loss:     0.1354 Validation Accuracy: 0.799800
# Epoch 60, CIFAR-10 Batch 3:  Loss:     0.0967 Validation Accuracy: 0.793800
# Epoch 60, CIFAR-10 Batch 4:  Loss:     0.1283 Validation Accuracy: 0.791400
# Epoch 60, CIFAR-10 Batch 5:  Loss:     0.0918 Validation Accuracy: 0.801800
# Epoch 61, CIFAR-10 Batch 1:  Loss:     0.1681 Validation Accuracy: 0.798800
# Epoch 61, CIFAR-10 Batch 2:  Loss:     0.1918 Validation Accuracy: 0.785400
# Epoch 61, CIFAR-10 Batch 3:  Loss:     0.1055 Validation Accuracy: 0.789400
# Epoch 61, CIFAR-10 Batch 4:  Loss:     0.1386 Validation Accuracy: 0.797000
# Epoch 61, CIFAR-10 Batch 5:  Loss:     0.1309 Validation Accuracy: 0.795200
# Epoch 62, CIFAR-10 Batch 1:  Loss:     0.1604 Validation Accuracy: 0.798400
# Epoch 62, CIFAR-10 Batch 2:  Loss:     0.1448 Validation Accuracy: 0.801000
# Epoch 62, CIFAR-10 Batch 3:  Loss:     0.0840 Validation Accuracy: 0.800200
# Epoch 62, CIFAR-10 Batch 4:  Loss:     0.1530 Validation Accuracy: 0.784400
# Epoch 62, CIFAR-10 Batch 5:  Loss:     0.1001 Validation Accuracy: 0.797000
# Epoch 63, CIFAR-10 Batch 1:  Loss:     0.1559 Validation Accuracy: 0.786200
# Epoch 63, CIFAR-10 Batch 2:  Loss:     0.1254 Validation Accuracy: 0.792600
# Epoch 63, CIFAR-10 Batch 3:  Loss:     0.1064 Validation Accuracy: 0.791200
# Epoch 63, CIFAR-10 Batch 4:  Loss:     0.1131 Validation Accuracy: 0.798000
# Epoch 63, CIFAR-10 Batch 5:  Loss:     0.1197 Validation Accuracy: 0.799200
# Epoch 64, CIFAR-10 Batch 1:  Loss:     0.1260 Validation Accuracy: 0.795200
# Epoch 64, CIFAR-10 Batch 2:  Loss:     0.1354 Validation Accuracy: 0.790000
# Epoch 64, CIFAR-10 Batch 3:  Loss:     0.0958 Validation Accuracy: 0.787600
# Epoch 64, CIFAR-10 Batch 4:  Loss:     0.1274 Validation Accuracy: 0.800000
# Epoch 64, CIFAR-10 Batch 5:  Loss:     0.1036 Validation Accuracy: 0.798400
# Epoch 65, CIFAR-10 Batch 1:  Loss:     0.1371 Validation Accuracy: 0.796800
# Epoch 65, CIFAR-10 Batch 2:  Loss:     0.1496 Validation Accuracy: 0.787600
# Epoch 65, CIFAR-10 Batch 3:  Loss:     0.0967 Validation Accuracy: 0.805200
# Epoch 65, CIFAR-10 Batch 4:  Loss:     0.1075 Validation Accuracy: 0.798400
# Epoch 65, CIFAR-10 Batch 5:  Loss:     0.0697 Validation Accuracy: 0.796600
# Epoch 66, CIFAR-10 Batch 1:  Loss:     0.1188 Validation Accuracy: 0.802800
# Epoch 66, CIFAR-10 Batch 2:  Loss:     0.1101 Validation Accuracy: 0.800000
# Epoch 66, CIFAR-10 Batch 3:  Loss:     0.0698 Validation Accuracy: 0.800800
# Epoch 66, CIFAR-10 Batch 4:  Loss:     0.1206 Validation Accuracy: 0.792400
# Epoch 66, CIFAR-10 Batch 5:  Loss:     0.0749 Validation Accuracy: 0.801200
# Epoch 67, CIFAR-10 Batch 1:  Loss:     0.1070 Validation Accuracy: 0.801600
# Epoch 67, CIFAR-10 Batch 2:  Loss:     0.1822 Validation Accuracy: 0.793800
# Epoch 67, CIFAR-10 Batch 3:  Loss:     0.0846 Validation Accuracy: 0.793600
# Epoch 67, CIFAR-10 Batch 4:  Loss:     0.0883 Validation Accuracy: 0.799000
# Epoch 67, CIFAR-10 Batch 5:  Loss:     0.0593 Validation Accuracy: 0.799000
# Epoch 68, CIFAR-10 Batch 1:  Loss:     0.1189 Validation Accuracy: 0.779800
# Epoch 68, CIFAR-10 Batch 2:  Loss:     0.1271 Validation Accuracy: 0.794400
# Epoch 68, CIFAR-10 Batch 3:  Loss:     0.0650 Validation Accuracy: 0.797200
# Epoch 68, CIFAR-10 Batch 4:  Loss:     0.1298 Validation Accuracy: 0.794800
# Epoch 68, CIFAR-10 Batch 5:  Loss:     0.0866 Validation Accuracy: 0.792000
# Epoch 69, CIFAR-10 Batch 1:  Loss:     0.1314 Validation Accuracy: 0.791600
# Epoch 69, CIFAR-10 Batch 2:  Loss:     0.1239 Validation Accuracy: 0.795400
# Epoch 69, CIFAR-10 Batch 3:  Loss:     0.0785 Validation Accuracy: 0.797400
# Epoch 69, CIFAR-10 Batch 4:  Loss:     0.0944 Validation Accuracy: 0.797800
# Epoch 69, CIFAR-10 Batch 5:  Loss:     0.0637 Validation Accuracy: 0.807400
# Epoch 70, CIFAR-10 Batch 1:  Loss:     0.1000 Validation Accuracy: 0.798800
# Epoch 70, CIFAR-10 Batch 2:  Loss:     0.1221 Validation Accuracy: 0.793400
# Epoch 70, CIFAR-10 Batch 3:  Loss:     0.0683 Validation Accuracy: 0.800400
# Epoch 70, CIFAR-10 Batch 4:  Loss:     0.0998 Validation Accuracy: 0.802800
# Epoch 70, CIFAR-10 Batch 5:  Loss:     0.0670 Validation Accuracy: 0.803000
# Epoch 71, CIFAR-10 Batch 1:  Loss:     0.1405 Validation Accuracy: 0.798200
# Epoch 71, CIFAR-10 Batch 2:  Loss:     0.1082 Validation Accuracy: 0.800000
# Epoch 71, CIFAR-10 Batch 3:  Loss:     0.0487 Validation Accuracy: 0.803000
# Epoch 71, CIFAR-10 Batch 4:  Loss:     0.1048 Validation Accuracy: 0.796800
# Epoch 71, CIFAR-10 Batch 5:  Loss:     0.0890 Validation Accuracy: 0.797800
# Epoch 72, CIFAR-10 Batch 1:  Loss:     0.1175 Validation Accuracy: 0.796200
# Epoch 72, CIFAR-10 Batch 2:  Loss:     0.0926 Validation Accuracy: 0.801400
# Epoch 72, CIFAR-10 Batch 3:  Loss:     0.0770 Validation Accuracy: 0.791000
# Epoch 72, CIFAR-10 Batch 4:  Loss:     0.0784 Validation Accuracy: 0.795000
# Epoch 72, CIFAR-10 Batch 5:  Loss:     0.0728 Validation Accuracy: 0.799600
# Epoch 73, CIFAR-10 Batch 1:  Loss:     0.1255 Validation Accuracy: 0.779200
# Epoch 73, CIFAR-10 Batch 2:  Loss:     0.1225 Validation Accuracy: 0.789600
# Epoch 73, CIFAR-10 Batch 3:  Loss:     0.0499 Validation Accuracy: 0.798400
# Epoch 73, CIFAR-10 Batch 4:  Loss:     0.0913 Validation Accuracy: 0.803600
# Epoch 73, CIFAR-10 Batch 5:  Loss:     0.0972 Validation Accuracy: 0.800000
# Epoch 74, CIFAR-10 Batch 1:  Loss:     0.0925 Validation Accuracy: 0.799400
# Epoch 74, CIFAR-10 Batch 2:  Loss:     0.1151 Validation Accuracy: 0.790800
# Epoch 74, CIFAR-10 Batch 3:  Loss:     0.0598 Validation Accuracy: 0.808000
# Epoch 74, CIFAR-10 Batch 4:  Loss:     0.0766 Validation Accuracy: 0.807400
# Epoch 74, CIFAR-10 Batch 5:  Loss:     0.0660 Validation Accuracy: 0.805200
# Epoch 75, CIFAR-10 Batch 1:  Loss:     0.1121 Validation Accuracy: 0.799800
# Epoch 75, CIFAR-10 Batch 2:  Loss:     0.0878 Validation Accuracy: 0.806400
# Epoch 75, CIFAR-10 Batch 3:  Loss:     0.0620 Validation Accuracy: 0.800400
# Epoch 75, CIFAR-10 Batch 4:  Loss:     0.0732 Validation Accuracy: 0.809000
# Epoch 75, CIFAR-10 Batch 5:  Loss:     0.0963 Validation Accuracy: 0.790800
# Epoch 76, CIFAR-10 Batch 1:  Loss:     0.0842 Validation Accuracy: 0.805200
# Epoch 76, CIFAR-10 Batch 2:  Loss:     0.0689 Validation Accuracy: 0.797800
# Epoch 76, CIFAR-10 Batch 3:  Loss:     0.0546 Validation Accuracy: 0.793800
# Epoch 76, CIFAR-10 Batch 4:  Loss:     0.0816 Validation Accuracy: 0.801200
# Epoch 76, CIFAR-10 Batch 5:  Loss:     0.0669 Validation Accuracy: 0.803400
# Epoch 77, CIFAR-10 Batch 1:  Loss:     0.0661 Validation Accuracy: 0.795600
# Epoch 77, CIFAR-10 Batch 2:  Loss:     0.0818 Validation Accuracy: 0.800200
# Epoch 77, CIFAR-10 Batch 3:  Loss:     0.0375 Validation Accuracy: 0.807600
# Epoch 77, CIFAR-10 Batch 4:  Loss:     0.1405 Validation Accuracy: 0.796600
# Epoch 77, CIFAR-10 Batch 5:  Loss:     0.0599 Validation Accuracy: 0.804600
# Epoch 78, CIFAR-10 Batch 1:  Loss:     0.1309 Validation Accuracy: 0.807200
# Epoch 78, CIFAR-10 Batch 2:  Loss:     0.0990 Validation Accuracy: 0.790000
# Epoch 78, CIFAR-10 Batch 3:  Loss:     0.0582 Validation Accuracy: 0.795200
# Epoch 78, CIFAR-10 Batch 4:  Loss:     0.0808 Validation Accuracy: 0.806000
# Epoch 78, CIFAR-10 Batch 5:  Loss:     0.0789 Validation Accuracy: 0.799600
# Epoch 79, CIFAR-10 Batch 1:  Loss:     0.0736 Validation Accuracy: 0.802800
# Epoch 79, CIFAR-10 Batch 2:  Loss:     0.0640 Validation Accuracy: 0.797600
# Epoch 79, CIFAR-10 Batch 3:  Loss:     0.0434 Validation Accuracy: 0.810400
# Epoch 79, CIFAR-10 Batch 4:  Loss:     0.0673 Validation Accuracy: 0.808800
# Epoch 79, CIFAR-10 Batch 5:  Loss:     0.0582 Validation Accuracy: 0.794200
# Epoch 80, CIFAR-10 Batch 1:  Loss:     0.0866 Validation Accuracy: 0.805400
# Epoch 80, CIFAR-10 Batch 2:  Loss:     0.0651 Validation Accuracy: 0.798200
# Epoch 80, CIFAR-10 Batch 3:  Loss:     0.0420 Validation Accuracy: 0.801600
# Epoch 80, CIFAR-10 Batch 4:  Loss:     0.0670 Validation Accuracy: 0.805000
# Epoch 80, CIFAR-10 Batch 5:  Loss:     0.0586 Validation Accuracy: 0.806400
# Epoch 81, CIFAR-10 Batch 1:  Loss:     0.0707 Validation Accuracy: 0.807800
# Epoch 81, CIFAR-10 Batch 2:  Loss:     0.0766 Validation Accuracy: 0.802600
# Epoch 81, CIFAR-10 Batch 3:  Loss:     0.0358 Validation Accuracy: 0.804800
# Epoch 81, CIFAR-10 Batch 4:  Loss:     0.0688 Validation Accuracy: 0.807800
# Epoch 81, CIFAR-10 Batch 5:  Loss:     0.0415 Validation Accuracy: 0.803400
# Epoch 82, CIFAR-10 Batch 1:  Loss:     0.0831 Validation Accuracy: 0.807600
# Epoch 82, CIFAR-10 Batch 2:  Loss:     0.0574 Validation Accuracy: 0.808600
# Epoch 82, CIFAR-10 Batch 3:  Loss:     0.0529 Validation Accuracy: 0.802600
# Epoch 82, CIFAR-10 Batch 4:  Loss:     0.0511 Validation Accuracy: 0.814800
# Epoch 82, CIFAR-10 Batch 5:  Loss:     0.0394 Validation Accuracy: 0.800600
# Epoch 83, CIFAR-10 Batch 1:  Loss:     0.1016 Validation Accuracy: 0.810800
# Epoch 83, CIFAR-10 Batch 2:  Loss:     0.0763 Validation Accuracy: 0.802200
# Epoch 83, CIFAR-10 Batch 3:  Loss:     0.0354 Validation Accuracy: 0.809000
# Epoch 83, CIFAR-10 Batch 4:  Loss:     0.0659 Validation Accuracy: 0.803200
# Epoch 83, CIFAR-10 Batch 5:  Loss:     0.0562 Validation Accuracy: 0.802000
# Epoch 84, CIFAR-10 Batch 1:  Loss:     0.0872 Validation Accuracy: 0.799800
# Epoch 84, CIFAR-10 Batch 2:  Loss:     0.0631 Validation Accuracy: 0.797600
# Epoch 84, CIFAR-10 Batch 3:  Loss:     0.0427 Validation Accuracy: 0.798800
# Epoch 84, CIFAR-10 Batch 4:  Loss:     0.0598 Validation Accuracy: 0.806600
# Epoch 84, CIFAR-10 Batch 5:  Loss:     0.0660 Validation Accuracy: 0.797800
# Epoch 85, CIFAR-10 Batch 1:  Loss:     0.0739 Validation Accuracy: 0.799400
# Epoch 85, CIFAR-10 Batch 2:  Loss:     0.0660 Validation Accuracy: 0.806800
# Epoch 85, CIFAR-10 Batch 3:  Loss:     0.0438 Validation Accuracy: 0.809000
# Epoch 85, CIFAR-10 Batch 4:  Loss:     0.0593 Validation Accuracy: 0.803400
# Epoch 85, CIFAR-10 Batch 5:  Loss:     0.0551 Validation Accuracy: 0.797800
# Epoch 86, CIFAR-10 Batch 1:  Loss:     0.0485 Validation Accuracy: 0.809200
# Epoch 86, CIFAR-10 Batch 2:  Loss:     0.0461 Validation Accuracy: 0.805200
# Epoch 86, CIFAR-10 Batch 3:  Loss:     0.0452 Validation Accuracy: 0.801200
# Epoch 86, CIFAR-10 Batch 4:  Loss:     0.0555 Validation Accuracy: 0.808400
# Epoch 86, CIFAR-10 Batch 5:  Loss:     0.0538 Validation Accuracy: 0.808000
# Epoch 87, CIFAR-10 Batch 1:  Loss:     0.0733 Validation Accuracy: 0.799200
# Epoch 87, CIFAR-10 Batch 2:  Loss:     0.0458 Validation Accuracy: 0.803600
# Epoch 87, CIFAR-10 Batch 3:  Loss:     0.0415 Validation Accuracy: 0.801200
# Epoch 87, CIFAR-10 Batch 4:  Loss:     0.0529 Validation Accuracy: 0.807800
# Epoch 87, CIFAR-10 Batch 5:  Loss:     0.0417 Validation Accuracy: 0.801200
# Epoch 88, CIFAR-10 Batch 1:  Loss:     0.0789 Validation Accuracy: 0.807600
# Epoch 88, CIFAR-10 Batch 2:  Loss:     0.0432 Validation Accuracy: 0.812400
# Epoch 88, CIFAR-10 Batch 3:  Loss:     0.0336 Validation Accuracy: 0.802000
# Epoch 88, CIFAR-10 Batch 4:  Loss:     0.0551 Validation Accuracy: 0.803600
# Epoch 88, CIFAR-10 Batch 5:  Loss:     0.0415 Validation Accuracy: 0.797800
# Epoch 89, CIFAR-10 Batch 1:  Loss:     0.0752 Validation Accuracy: 0.790200
# Epoch 89, CIFAR-10 Batch 2:  Loss:     0.0250 Validation Accuracy: 0.806800
# Epoch 89, CIFAR-10 Batch 3:  Loss:     0.0331 Validation Accuracy: 0.800600
# Epoch 89, CIFAR-10 Batch 4:  Loss:     0.0673 Validation Accuracy: 0.811000
# Epoch 89, CIFAR-10 Batch 5:  Loss:     0.0500 Validation Accuracy: 0.792800
# Epoch 90, CIFAR-10 Batch 1:  Loss:     0.0874 Validation Accuracy: 0.804800
# Epoch 90, CIFAR-10 Batch 2:  Loss:     0.0587 Validation Accuracy: 0.796600
# Epoch 90, CIFAR-10 Batch 3:  Loss:     0.0261 Validation Accuracy: 0.801400
# Epoch 90, CIFAR-10 Batch 4:  Loss:     0.0692 Validation Accuracy: 0.808400
# Epoch 90, CIFAR-10 Batch 5:  Loss:     0.0456 Validation Accuracy: 0.801600
# Epoch 91, CIFAR-10 Batch 1:  Loss:     0.0553 Validation Accuracy: 0.810600
# Epoch 91, CIFAR-10 Batch 2:  Loss:     0.0318 Validation Accuracy: 0.806400
# Epoch 91, CIFAR-10 Batch 3:  Loss:     0.0313 Validation Accuracy: 0.799400
# Epoch 91, CIFAR-10 Batch 4:  Loss:     0.0681 Validation Accuracy: 0.800800
# Epoch 91, CIFAR-10 Batch 5:  Loss:     0.0470 Validation Accuracy: 0.798800
# Epoch 92, CIFAR-10 Batch 1:  Loss:     0.0522 Validation Accuracy: 0.808400
# Epoch 92, CIFAR-10 Batch 2:  Loss:     0.0338 Validation Accuracy: 0.808200
# Epoch 92, CIFAR-10 Batch 3:  Loss:     0.0329 Validation Accuracy: 0.798200
# Epoch 92, CIFAR-10 Batch 4:  Loss:     0.0484 Validation Accuracy: 0.805200
# Epoch 92, CIFAR-10 Batch 5:  Loss:     0.0296 Validation Accuracy: 0.805200
# Epoch 93, CIFAR-10 Batch 1:  Loss:     0.0877 Validation Accuracy: 0.791000
# Epoch 93, CIFAR-10 Batch 2:  Loss:     0.0591 Validation Accuracy: 0.799400
# Epoch 93, CIFAR-10 Batch 3:  Loss:     0.0244 Validation Accuracy: 0.807400
# Epoch 93, CIFAR-10 Batch 4:  Loss:     0.0625 Validation Accuracy: 0.810400
# Epoch 93, CIFAR-10 Batch 5:  Loss:     0.0290 Validation Accuracy: 0.798400
# Epoch 94, CIFAR-10 Batch 1:  Loss:     0.0346 Validation Accuracy: 0.807400
# Epoch 94, CIFAR-10 Batch 2:  Loss:     0.0302 Validation Accuracy: 0.807000
# Epoch 94, CIFAR-10 Batch 3:  Loss:     0.0247 Validation Accuracy: 0.812600
# Epoch 94, CIFAR-10 Batch 4:  Loss:     0.0656 Validation Accuracy: 0.802400
# Epoch 94, CIFAR-10 Batch 5:  Loss:     0.0408 Validation Accuracy: 0.802400
# Epoch 95, CIFAR-10 Batch 1:  Loss:     0.0404 Validation Accuracy: 0.796600
# Epoch 95, CIFAR-10 Batch 2:  Loss:     0.0574 Validation Accuracy: 0.793800
# Epoch 95, CIFAR-10 Batch 3:  Loss:     0.0397 Validation Accuracy: 0.801200
# Epoch 95, CIFAR-10 Batch 4:  Loss:     0.0590 Validation Accuracy: 0.799000
# Epoch 95, CIFAR-10 Batch 5:  Loss:     0.0334 Validation Accuracy: 0.804200
# Epoch 96, CIFAR-10 Batch 1:  Loss:     0.0368 Validation Accuracy: 0.806400
# Epoch 96, CIFAR-10 Batch 2:  Loss:     0.0627 Validation Accuracy: 0.803600
# Epoch 96, CIFAR-10 Batch 3:  Loss:     0.0385 Validation Accuracy: 0.812800
# Epoch 96, CIFAR-10 Batch 4:  Loss:     0.0576 Validation Accuracy: 0.799800
# Epoch 96, CIFAR-10 Batch 5:  Loss:     0.0201 Validation Accuracy: 0.797800
# Epoch 97, CIFAR-10 Batch 1:  Loss:     0.0482 Validation Accuracy: 0.807400
# Epoch 97, CIFAR-10 Batch 2:  Loss:     0.0504 Validation Accuracy: 0.805000
# Epoch 97, CIFAR-10 Batch 3:  Loss:     0.0185 Validation Accuracy: 0.808400
# Epoch 97, CIFAR-10 Batch 4:  Loss:     0.0590 Validation Accuracy: 0.794600
# Epoch 97, CIFAR-10 Batch 5:  Loss:     0.0169 Validation Accuracy: 0.804000
# Epoch 98, CIFAR-10 Batch 1:  Loss:     0.0350 Validation Accuracy: 0.805400
# Epoch 98, CIFAR-10 Batch 2:  Loss:     0.0404 Validation Accuracy: 0.809200
# Epoch 98, CIFAR-10 Batch 3:  Loss:     0.0189 Validation Accuracy: 0.806600
# Epoch 98, CIFAR-10 Batch 4:  Loss:     0.0811 Validation Accuracy: 0.808000
# Epoch 98, CIFAR-10 Batch 5:  Loss:     0.0249 Validation Accuracy: 0.801800
# Epoch 99, CIFAR-10 Batch 1:  Loss:     0.0483 Validation Accuracy: 0.801800
# Epoch 99, CIFAR-10 Batch 2:  Loss:     0.0972 Validation Accuracy: 0.809400
# Epoch 99, CIFAR-10 Batch 3:  Loss:     0.0320 Validation Accuracy: 0.812000
# Epoch 99, CIFAR-10 Batch 4:  Loss:     0.0702 Validation Accuracy: 0.800600
# Epoch 99, CIFAR-10 Batch 5:  Loss:     0.0151 Validation Accuracy: 0.804800
# Epoch 100, CIFAR-10 Batch 1:  Loss:     0.0291 Validation Accuracy: 0.813000
# Epoch 100, CIFAR-10 Batch 2:  Loss:     0.0288 Validation Accuracy: 0.805800
# Epoch 100, CIFAR-10 Batch 3:  Loss:     0.0258 Validation Accuracy: 0.804800
# Epoch 100, CIFAR-10 Batch 4:  Loss:     0.0424 Validation Accuracy: 0.805600
# Epoch 100, CIFAR-10 Batch 5:  Loss:     0.0417 Validation Accuracy: 0.798200
# Epoch 101, CIFAR-10 Batch 1:  Loss:     0.0303 Validation Accuracy: 0.804400
# Epoch 101, CIFAR-10 Batch 2:  Loss:     0.0374 Validation Accuracy: 0.810000
# Epoch 101, CIFAR-10 Batch 3:  Loss:     0.0335 Validation Accuracy: 0.808400
# Epoch 101, CIFAR-10 Batch 4:  Loss:     0.0338 Validation Accuracy: 0.814000
# Epoch 101, CIFAR-10 Batch 5:  Loss:     0.0209 Validation Accuracy: 0.805200
# Epoch 102, CIFAR-10 Batch 1:  Loss:     0.0425 Validation Accuracy: 0.812600
# Epoch 102, CIFAR-10 Batch 2:  Loss:     0.0326 Validation Accuracy: 0.806200
# Epoch 102, CIFAR-10 Batch 3:  Loss:     0.0252 Validation Accuracy: 0.811600
# Epoch 102, CIFAR-10 Batch 4:  Loss:     0.0419 Validation Accuracy: 0.805000
# Epoch 102, CIFAR-10 Batch 5:  Loss:     0.0216 Validation Accuracy: 0.805400
# Epoch 103, CIFAR-10 Batch 1:  Loss:     0.0339 Validation Accuracy: 0.802000
# Epoch 103, CIFAR-10 Batch 2:  Loss:     0.0493 Validation Accuracy: 0.809000
# Epoch 103, CIFAR-10 Batch 3:  Loss:     0.0260 Validation Accuracy: 0.805600
# Epoch 103, CIFAR-10 Batch 4:  Loss:     0.0431 Validation Accuracy: 0.809800
# Epoch 103, CIFAR-10 Batch 5:  Loss:     0.0189 Validation Accuracy: 0.806600
# Epoch 104, CIFAR-10 Batch 1:  Loss:     0.0265 Validation Accuracy: 0.813800
# Epoch 104, CIFAR-10 Batch 2:  Loss:     0.0456 Validation Accuracy: 0.810400
# Epoch 104, CIFAR-10 Batch 3:  Loss:     0.0238 Validation Accuracy: 0.810800
# Epoch 104, CIFAR-10 Batch 4:  Loss:     0.0515 Validation Accuracy: 0.810600
# Epoch 104, CIFAR-10 Batch 5:  Loss:     0.0237 Validation Accuracy: 0.814200
# Epoch 105, CIFAR-10 Batch 1:  Loss:     0.0416 Validation Accuracy: 0.811000
# Epoch 105, CIFAR-10 Batch 2:  Loss:     0.0153 Validation Accuracy: 0.815200
# Epoch 105, CIFAR-10 Batch 3:  Loss:     0.0253 Validation Accuracy: 0.807400
# Epoch 105, CIFAR-10 Batch 4:  Loss:     0.0751 Validation Accuracy: 0.807400
# Epoch 105, CIFAR-10 Batch 5:  Loss:     0.0154 Validation Accuracy: 0.814200
# Epoch 106, CIFAR-10 Batch 1:  Loss:     0.0406 Validation Accuracy: 0.808000
# Epoch 106, CIFAR-10 Batch 2:  Loss:     0.0337 Validation Accuracy: 0.812400
# Epoch 106, CIFAR-10 Batch 3:  Loss:     0.0355 Validation Accuracy: 0.809200
# Epoch 106, CIFAR-10 Batch 4:  Loss:     0.0359 Validation Accuracy: 0.809600
# Epoch 106, CIFAR-10 Batch 5:  Loss:     0.0182 Validation Accuracy: 0.803600
# Epoch 107, CIFAR-10 Batch 1:  Loss:     0.0512 Validation Accuracy: 0.808000
# Epoch 107, CIFAR-10 Batch 2:  Loss:     0.0311 Validation Accuracy: 0.811400
# Epoch 107, CIFAR-10 Batch 3:  Loss:     0.0148 Validation Accuracy: 0.806600
# Epoch 107, CIFAR-10 Batch 4:  Loss:     0.0571 Validation Accuracy: 0.796000
# Epoch 107, CIFAR-10 Batch 5:  Loss:     0.0213 Validation Accuracy: 0.811600
# Epoch 108, CIFAR-10 Batch 1:  Loss:     0.0565 Validation Accuracy: 0.802800
# Epoch 108, CIFAR-10 Batch 2:  Loss:     0.0326 Validation Accuracy: 0.804400
# Epoch 108, CIFAR-10 Batch 3:  Loss:     0.0235 Validation Accuracy: 0.806800
# Epoch 108, CIFAR-10 Batch 4:  Loss:     0.0478 Validation Accuracy: 0.802200
# Epoch 108, CIFAR-10 Batch 5:  Loss:     0.0260 Validation Accuracy: 0.800200
# Epoch 109, CIFAR-10 Batch 1:  Loss:     0.0314 Validation Accuracy: 0.807800
# Epoch 109, CIFAR-10 Batch 2:  Loss:     0.0268 Validation Accuracy: 0.813200
# Epoch 109, CIFAR-10 Batch 3:  Loss:     0.0182 Validation Accuracy: 0.814400
# Epoch 109, CIFAR-10 Batch 4:  Loss:     0.0504 Validation Accuracy: 0.811400
# Epoch 109, CIFAR-10 Batch 5:  Loss:     0.0142 Validation Accuracy: 0.809000
# Epoch 110, CIFAR-10 Batch 1:  Loss:     0.0245 Validation Accuracy: 0.811200
# Epoch 110, CIFAR-10 Batch 2:  Loss:     0.0282 Validation Accuracy: 0.806200
# Epoch 110, CIFAR-10 Batch 3:  Loss:     0.0195 Validation Accuracy: 0.804600
# Epoch 110, CIFAR-10 Batch 4:  Loss:     0.0294 Validation Accuracy: 0.812600
# Epoch 110, CIFAR-10 Batch 5:  Loss:     0.0194 Validation Accuracy: 0.806400
# Epoch 111, CIFAR-10 Batch 1:  Loss:     0.0366 Validation Accuracy: 0.800600
# Epoch 111, CIFAR-10 Batch 2:  Loss:     0.0245 Validation Accuracy: 0.815200
# Epoch 111, CIFAR-10 Batch 3:  Loss:     0.0156 Validation Accuracy: 0.806000
# Epoch 111, CIFAR-10 Batch 4:  Loss:     0.0351 Validation Accuracy: 0.809400
# Epoch 111, CIFAR-10 Batch 5:  Loss:     0.0170 Validation Accuracy: 0.813400
# Epoch 112, CIFAR-10 Batch 1:  Loss:     0.0204 Validation Accuracy: 0.808200
# Epoch 112, CIFAR-10 Batch 2:  Loss:     0.0270 Validation Accuracy: 0.809800
# Epoch 112, CIFAR-10 Batch 3:  Loss:     0.0131 Validation Accuracy: 0.811000
# Epoch 112, CIFAR-10 Batch 4:  Loss:     0.0325 Validation Accuracy: 0.807800
# Epoch 112, CIFAR-10 Batch 5:  Loss:     0.0171 Validation Accuracy: 0.817200
# Epoch 113, CIFAR-10 Batch 1:  Loss:     0.0256 Validation Accuracy: 0.815800
# Epoch 113, CIFAR-10 Batch 2:  Loss:     0.0260 Validation Accuracy: 0.802600
# Epoch 113, CIFAR-10 Batch 3:  Loss:     0.0126 Validation Accuracy: 0.815600
# Epoch 113, CIFAR-10 Batch 4:  Loss:     0.0407 Validation Accuracy: 0.808000
# Epoch 113, CIFAR-10 Batch 5:  Loss:     0.0090 Validation Accuracy: 0.814800
# Epoch 114, CIFAR-10 Batch 1:  Loss:     0.0141 Validation Accuracy: 0.815800
# Epoch 114, CIFAR-10 Batch 2:  Loss:     0.0140 Validation Accuracy: 0.819400
# Epoch 114, CIFAR-10 Batch 3:  Loss:     0.0181 Validation Accuracy: 0.806400
# Epoch 114, CIFAR-10 Batch 4:  Loss:     0.0235 Validation Accuracy: 0.812600
# Epoch 114, CIFAR-10 Batch 5:  Loss:     0.0076 Validation Accuracy: 0.807000
# Epoch 115, CIFAR-10 Batch 1:  Loss:     0.0387 Validation Accuracy: 0.803800
# Epoch 115, CIFAR-10 Batch 2:  Loss:     0.0345 Validation Accuracy: 0.807400
# Epoch 115, CIFAR-10 Batch 3:  Loss:     0.0138 Validation Accuracy: 0.812400
# Epoch 115, CIFAR-10 Batch 4:  Loss:     0.0404 Validation Accuracy: 0.803200
# Epoch 115, CIFAR-10 Batch 5:  Loss:     0.0121 Validation Accuracy: 0.812000
# Epoch 116, CIFAR-10 Batch 1:  Loss:     0.0211 Validation Accuracy: 0.811400
# Epoch 116, CIFAR-10 Batch 2:  Loss:     0.0120 Validation Accuracy: 0.810000
# Epoch 116, CIFAR-10 Batch 3:  Loss:     0.0178 Validation Accuracy: 0.805000
# Epoch 116, CIFAR-10 Batch 4:  Loss:     0.0484 Validation Accuracy: 0.808400
# Epoch 116, CIFAR-10 Batch 5:  Loss:     0.0124 Validation Accuracy: 0.807600
# Epoch 117, CIFAR-10 Batch 1:  Loss:     0.0086 Validation Accuracy: 0.807200
# Epoch 117, CIFAR-10 Batch 2:  Loss:     0.0111 Validation Accuracy: 0.816400
# Epoch 117, CIFAR-10 Batch 3:  Loss:     0.0264 Validation Accuracy: 0.805400
# Epoch 117, CIFAR-10 Batch 4:  Loss:     0.0394 Validation Accuracy: 0.810200
# Epoch 117, CIFAR-10 Batch 5:  Loss:     0.0084 Validation Accuracy: 0.808200
# Epoch 118, CIFAR-10 Batch 1:  Loss:     0.0296 Validation Accuracy: 0.811600
# Epoch 118, CIFAR-10 Batch 2:  Loss:     0.0178 Validation Accuracy: 0.809400
# Epoch 118, CIFAR-10 Batch 3:  Loss:     0.0140 Validation Accuracy: 0.808400
# Epoch 118, CIFAR-10 Batch 4:  Loss:     0.0359 Validation Accuracy: 0.809000
# Epoch 118, CIFAR-10 Batch 5:  Loss:     0.0181 Validation Accuracy: 0.810000
# Epoch 119, CIFAR-10 Batch 1:  Loss:     0.0240 Validation Accuracy: 0.808000
# Epoch 119, CIFAR-10 Batch 2:  Loss:     0.0164 Validation Accuracy: 0.808400
# Epoch 119, CIFAR-10 Batch 3:  Loss:     0.0174 Validation Accuracy: 0.807000
# Epoch 119, CIFAR-10 Batch 4:  Loss:     0.0270 Validation Accuracy: 0.815000
# Epoch 119, CIFAR-10 Batch 5:  Loss:     0.0122 Validation Accuracy: 0.808600
# Epoch 120, CIFAR-10 Batch 1:  Loss:     0.0405 Validation Accuracy: 0.810800
# Epoch 120, CIFAR-10 Batch 2:  Loss:     0.0116 Validation Accuracy: 0.811600
# Epoch 120, CIFAR-10 Batch 3:  Loss:     0.0114 Validation Accuracy: 0.805800
# Epoch 120, CIFAR-10 Batch 4:  Loss:     0.0316 Validation Accuracy: 0.814000
# Epoch 120, CIFAR-10 Batch 5:  Loss:     0.0097 Validation Accuracy: 0.803000
# Epoch 121, CIFAR-10 Batch 1:  Loss:     0.0271 Validation Accuracy: 0.818000
# Epoch 121, CIFAR-10 Batch 2:  Loss:     0.0258 Validation Accuracy: 0.810200
# Epoch 121, CIFAR-10 Batch 3:  Loss:     0.0186 Validation Accuracy: 0.809400
# Epoch 121, CIFAR-10 Batch 4:  Loss:     0.0608 Validation Accuracy: 0.810000
# Epoch 121, CIFAR-10 Batch 5:  Loss:     0.0066 Validation Accuracy: 0.807200
# Epoch 122, CIFAR-10 Batch 1:  Loss:     0.0253 Validation Accuracy: 0.809600
# Epoch 122, CIFAR-10 Batch 2:  Loss:     0.0136 Validation Accuracy: 0.814400
# Epoch 122, CIFAR-10 Batch 3:  Loss:     0.0100 Validation Accuracy: 0.805400
# Epoch 122, CIFAR-10 Batch 4:  Loss:     0.0409 Validation Accuracy: 0.806200
# Epoch 122, CIFAR-10 Batch 5:  Loss:     0.0106 Validation Accuracy: 0.813000
# Epoch 123, CIFAR-10 Batch 1:  Loss:     0.0080 Validation Accuracy: 0.806600
# Epoch 123, CIFAR-10 Batch 2:  Loss:     0.0185 Validation Accuracy: 0.809400
# Epoch 123, CIFAR-10 Batch 3:  Loss:     0.0094 Validation Accuracy: 0.800600
# Epoch 123, CIFAR-10 Batch 4:  Loss:     0.0493 Validation Accuracy: 0.807000
# Epoch 123, CIFAR-10 Batch 5:  Loss:     0.0119 Validation Accuracy: 0.809800
# Epoch 124, CIFAR-10 Batch 1:  Loss:     0.0164 Validation Accuracy: 0.807800
# Epoch 124, CIFAR-10 Batch 2:  Loss:     0.0185 Validation Accuracy: 0.816800
# Epoch 124, CIFAR-10 Batch 3:  Loss:     0.0136 Validation Accuracy: 0.811200
# Epoch 124, CIFAR-10 Batch 4:  Loss:     0.0189 Validation Accuracy: 0.815400
# Epoch 124, CIFAR-10 Batch 5:  Loss:     0.0124 Validation Accuracy: 0.811400
# Epoch 125, CIFAR-10 Batch 1:  Loss:     0.0122 Validation Accuracy: 0.809800
# Epoch 125, CIFAR-10 Batch 2:  Loss:     0.0094 Validation Accuracy: 0.811600
# Epoch 125, CIFAR-10 Batch 3:  Loss:     0.0079 Validation Accuracy: 0.814400
# Epoch 125, CIFAR-10 Batch 4:  Loss:     0.0257 Validation Accuracy: 0.818200
# Epoch 125, CIFAR-10 Batch 5:  Loss:     0.0070 Validation Accuracy: 0.810400
# Epoch 126, CIFAR-10 Batch 1:  Loss:     0.0470 Validation Accuracy: 0.803000
# Epoch 126, CIFAR-10 Batch 2:  Loss:     0.0053 Validation Accuracy: 0.806000
# Epoch 126, CIFAR-10 Batch 3:  Loss:     0.0176 Validation Accuracy: 0.806400
# Epoch 126, CIFAR-10 Batch 4:  Loss:     0.0327 Validation Accuracy: 0.816400
# ...
# Epoch 159, CIFAR-10 Batch 4:  Loss:     0.0143 Validation Accuracy: 0.814400
# Epoch 159, CIFAR-10 Batch 5:  Loss:     0.0027 Validation Accuracy: 0.811800
# Epoch 160, CIFAR-10 Batch 1:  Loss:     0.0102 Validation Accuracy: 0.813000
# Epoch 160, CIFAR-10 Batch 2:  Loss:     0.0089 Validation Accuracy: 0.796800
# Epoch 160, CIFAR-10 Batch 3:  Loss:     0.0018 Validation Accuracy: 0.819200
# Epoch 160, CIFAR-10 Batch 4:  Loss:     0.0102 Validation Accuracy: 0.815000
# Epoch 160, CIFAR-10 Batch 5:  Loss:     0.0045 Validation Accuracy: 0.812600
# Epoch 161, CIFAR-10 Batch 1:  Loss:     0.0047 Validation Accuracy: 0.814000
# Epoch 161, CIFAR-10 Batch 2:  Loss:     0.0141 Validation Accuracy: 0.810200
# Epoch 161, CIFAR-10 Batch 3:  Loss:     0.0039 Validation Accuracy: 0.819000
# Epoch 161, CIFAR-10 Batch 4:  Loss:     0.0100 Validation Accuracy: 0.811800
# Epoch 161, CIFAR-10 Batch 5:  Loss:     0.0019 Validation Accuracy: 0.819800
# Epoch 162, CIFAR-10 Batch 1:  Loss:     0.0039 Validation Accuracy: 0.814800
# Epoch 162, CIFAR-10 Batch 2:  Loss:     0.0049 Validation Accuracy: 0.815400
# Epoch 162, CIFAR-10 Batch 3:  Loss:     0.0031 Validation Accuracy: 0.808800
# Epoch 162, CIFAR-10 Batch 4:  Loss:     0.0113 Validation Accuracy: 0.814000
# Epoch 162, CIFAR-10 Batch 5:  Loss:     0.0020 Validation Accuracy: 0.818200
# Epoch 163, CIFAR-10 Batch 1:  Loss:     0.0052 Validation Accuracy: 0.814600
# Epoch 163, CIFAR-10 Batch 2:  Loss:     0.0016 Validation Accuracy: 0.819800
# Epoch 163, CIFAR-10 Batch 3:  Loss:     0.0034 Validation Accuracy: 0.812400
# Epoch 163, CIFAR-10 Batch 4:  Loss:     0.0173 Validation Accuracy: 0.816200
# Epoch 163, CIFAR-10 Batch 5:  Loss:     0.0040 Validation Accuracy: 0.817800
# Epoch 164, CIFAR-10 Batch 1:  Loss:     0.0014 Validation Accuracy: 0.814800
# Epoch 164, CIFAR-10 Batch 2:  Loss:     0.0041 Validation Accuracy: 0.820200
# Epoch 164, CIFAR-10 Batch 3:  Loss:     0.0040 Validation Accuracy: 0.814600
# Epoch 164, CIFAR-10 Batch 4:  Loss:     0.0109 Validation Accuracy: 0.816400
# Epoch 164, CIFAR-10 Batch 5:  Loss:     0.0015 Validation Accuracy: 0.814600
# Epoch 165, CIFAR-10 Batch 1:  Loss:     0.0161 Validation Accuracy: 0.813400
# Epoch 165, CIFAR-10 Batch 2:  Loss:     0.0131 Validation Accuracy: 0.817000
# Epoch 165, CIFAR-10 Batch 3:  Loss:     0.0044 Validation Accuracy: 0.819200
# Epoch 165, CIFAR-10 Batch 4:  Loss:     0.0085 Validation Accuracy: 0.816600
# Epoch 165, CIFAR-10 Batch 5:  Loss:     0.0110 Validation Accuracy: 0.816200
# Epoch 166, CIFAR-10 Batch 1:  Loss:     0.0035 Validation Accuracy: 0.809400
# Epoch 166, CIFAR-10 Batch 2:  Loss:     0.0032 Validation Accuracy: 0.815800
# Epoch 166, CIFAR-10 Batch 3:  Loss:     0.0027 Validation Accuracy: 0.814200
# Epoch 166, CIFAR-10 Batch 4:  Loss:     0.0023 Validation Accuracy: 0.817400
# Epoch 166, CIFAR-10 Batch 5:  Loss:     0.0025 Validation Accuracy: 0.809200
# Epoch 167, CIFAR-10 Batch 1:  Loss:     0.0034 Validation Accuracy: 0.816600
# Epoch 167, CIFAR-10 Batch 2:  Loss:     0.0069 Validation Accuracy: 0.805200
# Epoch 167, CIFAR-10 Batch 3:  Loss:     0.0012 Validation Accuracy: 0.813000
# Epoch 167, CIFAR-10 Batch 4:  Loss:     0.0069 Validation Accuracy: 0.816200
# Epoch 167, CIFAR-10 Batch 5:  Loss:     0.0021 Validation Accuracy: 0.813400
# Epoch 168, CIFAR-10 Batch 1:  Loss:     0.0022 Validation Accuracy: 0.811800
# Epoch 168, CIFAR-10 Batch 2:  Loss:     0.0026 Validation Accuracy: 0.812400
# Epoch 168, CIFAR-10 Batch 3:  Loss:     0.0023 Validation Accuracy: 0.816800
# Epoch 168, CIFAR-10 Batch 4:  Loss:     0.0048 Validation Accuracy: 0.809400
# Epoch 168, CIFAR-10 Batch 5:  Loss:     0.0037 Validation Accuracy: 0.812600
# Epoch 169, CIFAR-10 Batch 1:  Loss:     0.0023 Validation Accuracy: 0.813400
# Epoch 169, CIFAR-10 Batch 2:  Loss:     0.0058 Validation Accuracy: 0.805600
# Epoch 169, CIFAR-10 Batch 3:  Loss:     0.0033 Validation Accuracy: 0.814000
# Epoch 169, CIFAR-10 Batch 4:  Loss:     0.0072 Validation Accuracy: 0.808600
# Epoch 169, CIFAR-10 Batch 5:  Loss:     0.0017 Validation Accuracy: 0.810400
# Epoch 170, CIFAR-10 Batch 1:  Loss:     0.0044 Validation Accuracy: 0.809000
# Epoch 170, CIFAR-10 Batch 2:  Loss:     0.0080 Validation Accuracy: 0.805400
# Epoch 170, CIFAR-10 Batch 3:  Loss:     0.0043 Validation Accuracy: 0.818800
# Epoch 170, CIFAR-10 Batch 4:  Loss:     0.0057 Validation Accuracy: 0.821200
# Epoch 170, CIFAR-10 Batch 5:  Loss:     0.0026 Validation Accuracy: 0.815600
# Epoch 171, CIFAR-10 Batch 1:  Loss:     0.0034 Validation Accuracy: 0.815000
# Epoch 171, CIFAR-10 Batch 2:  Loss:     0.0025 Validation Accuracy: 0.812800
# Epoch 171, CIFAR-10 Batch 3:  Loss:     0.0044 Validation Accuracy: 0.813800
# Epoch 171, CIFAR-10 Batch 4:  Loss:     0.0031 Validation Accuracy: 0.813600
# Epoch 171, CIFAR-10 Batch 5:  Loss:     0.0039 Validation Accuracy: 0.815200
# Epoch 172, CIFAR-10 Batch 1:  Loss:     0.0043 Validation Accuracy: 0.814800
# Epoch 172, CIFAR-10 Batch 2:  Loss:     0.0017 Validation Accuracy: 0.811000
# Epoch 172, CIFAR-10 Batch 3:  Loss:     0.0017 Validation Accuracy: 0.811200
# Epoch 172, CIFAR-10 Batch 4:  Loss:     0.0022 Validation Accuracy: 0.811400
# Epoch 172, CIFAR-10 Batch 5:  Loss:     0.0013 Validation Accuracy: 0.808200
# Epoch 173, CIFAR-10 Batch 1:  Loss:     0.0041 Validation Accuracy: 0.812400
# Epoch 173, CIFAR-10 Batch 2:  Loss:     0.0011 Validation Accuracy: 0.816600
# Epoch 173, CIFAR-10 Batch 3:  Loss:     0.0041 Validation Accuracy: 0.809600
# Epoch 173, CIFAR-10 Batch 4:  Loss:     0.0022 Validation Accuracy: 0.813400
# Epoch 173, CIFAR-10 Batch 5:  Loss:     0.0018 Validation Accuracy: 0.817400
# Epoch 174, CIFAR-10 Batch 1:  Loss:     0.0024 Validation Accuracy: 0.808600
# Epoch 174, CIFAR-10 Batch 2:  Loss:     0.0010 Validation Accuracy: 0.810600
# Epoch 174, CIFAR-10 Batch 3:  Loss:     0.0007 Validation Accuracy: 0.813600
# Epoch 174, CIFAR-10 Batch 4:  Loss:     0.0040 Validation Accuracy: 0.812800
# Epoch 174, CIFAR-10 Batch 5:  Loss:     0.0026 Validation Accuracy: 0.811800
# Epoch 175, CIFAR-10 Batch 1:  Loss:     0.0066 Validation Accuracy: 0.815600
# Epoch 175, CIFAR-10 Batch 2:  Loss:     0.0087 Validation Accuracy: 0.814200
# Epoch 175, CIFAR-10 Batch 3:  Loss:     0.0011 Validation Accuracy: 0.815400
# Epoch 175, CIFAR-10 Batch 4:  Loss:     0.0048 Validation Accuracy: 0.810800
# Epoch 175, CIFAR-10 Batch 5:  Loss:     0.0030 Validation Accuracy: 0.813200
# Epoch 176, CIFAR-10 Batch 1:  Loss:     0.0040 Validation Accuracy: 0.816600
# Epoch 176, CIFAR-10 Batch 2:  Loss:     0.0064 Validation Accuracy: 0.815000
# Epoch 176, CIFAR-10 Batch 3:  Loss:     0.0023 Validation Accuracy: 0.815200
# Epoch 176, CIFAR-10 Batch 4:  Loss:     0.0128 Validation Accuracy: 0.805200
# Epoch 176, CIFAR-10 Batch 5:  Loss:     0.0041 Validation Accuracy: 0.817200
# Epoch 177, CIFAR-10 Batch 1:  Loss:     0.0040 Validation Accuracy: 0.815200
# Epoch 177, CIFAR-10 Batch 2:  Loss:     0.0064 Validation Accuracy: 0.819400
# Epoch 177, CIFAR-10 Batch 3:  Loss:     0.0007 Validation Accuracy: 0.817000
# Epoch 177, CIFAR-10 Batch 4:  Loss:     0.0176 Validation Accuracy: 0.811800
# Epoch 177, CIFAR-10 Batch 5:  Loss:     0.0047 Validation Accuracy: 0.815000
# Epoch 178, CIFAR-10 Batch 1:  Loss:     0.0105 Validation Accuracy: 0.814000
# Epoch 178, CIFAR-10 Batch 2:  Loss:     0.0041 Validation Accuracy: 0.815200
# Epoch 178, CIFAR-10 Batch 3:  Loss:     0.0012 Validation Accuracy: 0.817800
# Epoch 178, CIFAR-10 Batch 4:  Loss:     0.0070 Validation Accuracy: 0.815600
# Epoch 178, CIFAR-10 Batch 5:  Loss:     0.0031 Validation Accuracy: 0.817000
# Epoch 179, CIFAR-10 Batch 1:  Loss:     0.0013 Validation Accuracy: 0.812800
# Epoch 179, CIFAR-10 Batch 2:  Loss:     0.0028 Validation Accuracy: 0.815000
# Epoch 179, CIFAR-10 Batch 3:  Loss:     0.0007 Validation Accuracy: 0.820200
# Epoch 179, CIFAR-10 Batch 4:  Loss:     0.0015 Validation Accuracy: 0.823400
# Epoch 179, CIFAR-10 Batch 5:  Loss:     0.0017 Validation Accuracy: 0.811800
# Epoch 180, CIFAR-10 Batch 1:  Loss:     0.0101 Validation Accuracy: 0.809000
# Epoch 180, CIFAR-10 Batch 2:  Loss:     0.0042 Validation Accuracy: 0.811400
# Epoch 180, CIFAR-10 Batch 3:  Loss:     0.0011 Validation Accuracy: 0.813200
# Epoch 180, CIFAR-10 Batch 4:  Loss:     0.0035 Validation Accuracy: 0.817400
# Epoch 180, CIFAR-10 Batch 5:  Loss:     0.0008 Validation Accuracy: 0.810800
# Epoch 181, CIFAR-10 Batch 1:  Loss:     0.0080 Validation Accuracy: 0.813600
# Epoch 181, CIFAR-10 Batch 2:  Loss:     0.0024 Validation Accuracy: 0.814600
# Epoch 181, CIFAR-10 Batch 3:  Loss:     0.0014 Validation Accuracy: 0.808600
# Epoch 181, CIFAR-10 Batch 4:  Loss:     0.0097 Validation Accuracy: 0.814400
# Epoch 181, CIFAR-10 Batch 5:  Loss:     0.0026 Validation Accuracy: 0.810000
# Epoch 182, CIFAR-10 Batch 1:  Loss:     0.0073 Validation Accuracy: 0.810600
# Epoch 182, CIFAR-10 Batch 2:  Loss:     0.0043 Validation Accuracy: 0.814200
# Epoch 182, CIFAR-10 Batch 3:  Loss:     0.0014 Validation Accuracy: 0.810400
# Epoch 182, CIFAR-10 Batch 4:  Loss:     0.0038 Validation Accuracy: 0.809000
# Epoch 182, CIFAR-10 Batch 5:  Loss:     0.0016 Validation Accuracy: 0.811600
# Epoch 183, CIFAR-10 Batch 1:  Loss:     0.0056 Validation Accuracy: 0.814800
# Epoch 183, CIFAR-10 Batch 2:  Loss:     0.0022 Validation Accuracy: 0.812800
# Epoch 183, CIFAR-10 Batch 3:  Loss:     0.0027 Validation Accuracy: 0.814200
# Epoch 183, CIFAR-10 Batch 4:  Loss:     0.0020 Validation Accuracy: 0.818800
# Epoch 183, CIFAR-10 Batch 5:  Loss:     0.0020 Validation Accuracy: 0.815800
# Epoch 184, CIFAR-10 Batch 1:  Loss:     0.0078 Validation Accuracy: 0.817400
# Epoch 184, CIFAR-10 Batch 2:  Loss:     0.0005 Validation Accuracy: 0.819200
# Epoch 184, CIFAR-10 Batch 3:  Loss:     0.0011 Validation Accuracy: 0.815400
# Epoch 184, CIFAR-10 Batch 4:  Loss:     0.0029 Validation Accuracy: 0.822200
# Epoch 184, CIFAR-10 Batch 5:  Loss:     0.0020 Validation Accuracy: 0.808600
# Epoch 185, CIFAR-10 Batch 1:  Loss:     0.0060 Validation Accuracy: 0.812200
# Epoch 185, CIFAR-10 Batch 2:  Loss:     0.0046 Validation Accuracy: 0.812800
# Epoch 185, CIFAR-10 Batch 3:  Loss:     0.0014 Validation Accuracy: 0.819000
# Epoch 185, CIFAR-10 Batch 4:  Loss:     0.0052 Validation Accuracy: 0.816400
# Epoch 185, CIFAR-10 Batch 5:  Loss:     0.0046 Validation Accuracy: 0.813000
# Epoch 186, CIFAR-10 Batch 1:  Loss:     0.0028 Validation Accuracy: 0.819800
# Epoch 186, CIFAR-10 Batch 2:  Loss:     0.0055 Validation Accuracy: 0.810000
# Epoch 186, CIFAR-10 Batch 3:  Loss:     0.0013 Validation Accuracy: 0.816600
# Epoch 186, CIFAR-10 Batch 4:  Loss:     0.0020 Validation Accuracy: 0.820000
# Epoch 186, CIFAR-10 Batch 5:  Loss:     0.0018 Validation Accuracy: 0.816600
# Epoch 187, CIFAR-10 Batch 1:  Loss:     0.0028 Validation Accuracy: 0.816800
# Epoch 187, CIFAR-10 Batch 2:  Loss:     0.0037 Validation Accuracy: 0.813200
# Epoch 187, CIFAR-10 Batch 3:  Loss:     0.0001 Validation Accuracy: 0.818200
# Epoch 187, CIFAR-10 Batch 4:  Loss:     0.0053 Validation Accuracy: 0.816200
# Epoch 187, CIFAR-10 Batch 5:  Loss:     0.0037 Validation Accuracy: 0.816000
# Epoch 188, CIFAR-10 Batch 1:  Loss:     0.0029 Validation Accuracy: 0.804600
# Epoch 188, CIFAR-10 Batch 2:  Loss:     0.0012 Validation Accuracy: 0.813200
# Epoch 188, CIFAR-10 Batch 3:  Loss:     0.0005 Validation Accuracy: 0.817800
# Epoch 188, CIFAR-10 Batch 4:  Loss:     0.0007 Validation Accuracy: 0.818600
# Epoch 188, CIFAR-10 Batch 5:  Loss:     0.0014 Validation Accuracy: 0.816800
# Epoch 189, CIFAR-10 Batch 1:  Loss:     0.0022 Validation Accuracy: 0.805200
# Epoch 189, CIFAR-10 Batch 2:  Loss:     0.0021 Validation Accuracy: 0.818800
# Epoch 189, CIFAR-10 Batch 3:  Loss:     0.0011 Validation Accuracy: 0.817000
# Epoch 189, CIFAR-10 Batch 4:  Loss:     0.0026 Validation Accuracy: 0.819200
# Epoch 189, CIFAR-10 Batch 5:  Loss:     0.0033 Validation Accuracy: 0.813400
# Epoch 190, CIFAR-10 Batch 1:  Loss:     0.0086 Validation Accuracy: 0.814400
# Epoch 190, CIFAR-10 Batch 2:  Loss:     0.0018 Validation Accuracy: 0.815200
# Epoch 190, CIFAR-10 Batch 3:  Loss:     0.0019 Validation Accuracy: 0.819800
# Epoch 190, CIFAR-10 Batch 4:  Loss:     0.0033 Validation Accuracy: 0.818400
# Epoch 190, CIFAR-10 Batch 5:  Loss:     0.0103 Validation Accuracy: 0.808600
# Epoch 191, CIFAR-10 Batch 1:  Loss:     0.0015 Validation Accuracy: 0.819000
# Epoch 191, CIFAR-10 Batch 2:  Loss:     0.0010 Validation Accuracy: 0.799200
# Epoch 191, CIFAR-10 Batch 3:  Loss:     0.0035 Validation Accuracy: 0.818200
# Epoch 191, CIFAR-10 Batch 4:  Loss:     0.0015 Validation Accuracy: 0.820600
# Epoch 191, CIFAR-10 Batch 5:  Loss:     0.0011 Validation Accuracy: 0.815000
# Epoch 192, CIFAR-10 Batch 1:  Loss:     0.0051 Validation Accuracy: 0.812200
# Epoch 192, CIFAR-10 Batch 2:  Loss:     0.0016 Validation Accuracy: 0.812800
# Epoch 192, CIFAR-10 Batch 3:  Loss:     0.0016 Validation Accuracy: 0.817200
# Epoch 192, CIFAR-10 Batch 4:  Loss:     0.0024 Validation Accuracy: 0.818400
# Epoch 192, CIFAR-10 Batch 5:  Loss:     0.0013 Validation Accuracy: 0.815000
# Epoch 193, CIFAR-10 Batch 1:  Loss:     0.0100 Validation Accuracy: 0.817000
# Epoch 193, CIFAR-10 Batch 2:  Loss:     0.0044 Validation Accuracy: 0.815800
# Epoch 193, CIFAR-10 Batch 3:  Loss:     0.0035 Validation Accuracy: 0.821000
# Epoch 193, CIFAR-10 Batch 4:  Loss:     0.0022 Validation Accuracy: 0.811400
# Epoch 193, CIFAR-10 Batch 5:  Loss:     0.0016 Validation Accuracy: 0.823400
# Epoch 194, CIFAR-10 Batch 1:  Loss:     0.0034 Validation Accuracy: 0.815600
# Epoch 194, CIFAR-10 Batch 2:  Loss:     0.0040 Validation Accuracy: 0.814600
# Epoch 194, CIFAR-10 Batch 3:  Loss:     0.0013 Validation Accuracy: 0.818800
# Epoch 194, CIFAR-10 Batch 4:  Loss:     0.0011 Validation Accuracy: 0.817000
# Epoch 194, CIFAR-10 Batch 5:  Loss:     0.0018 Validation Accuracy: 0.813000
# Epoch 195, CIFAR-10 Batch 1:  Loss:     0.0019 Validation Accuracy: 0.813200
# Epoch 195, CIFAR-10 Batch 2:  Loss:     0.0065 Validation Accuracy: 0.815000
# Epoch 195, CIFAR-10 Batch 3:  Loss:     0.0037 Validation Accuracy: 0.815800
# Epoch 195, CIFAR-10 Batch 4:  Loss:     0.0021 Validation Accuracy: 0.823000
# Epoch 195, CIFAR-10 Batch 5:  Loss:     0.0010 Validation Accuracy: 0.812200
# Epoch 196, CIFAR-10 Batch 1:  Loss:     0.0067 Validation Accuracy: 0.807000
# Epoch 196, CIFAR-10 Batch 2:  Loss:     0.0035 Validation Accuracy: 0.814200
# Epoch 196, CIFAR-10 Batch 3:  Loss:     0.0014 Validation Accuracy: 0.821200
# Epoch 196, CIFAR-10 Batch 4:  Loss:     0.0026 Validation Accuracy: 0.822400
# Epoch 196, CIFAR-10 Batch 5:  Loss:     0.0014 Validation Accuracy: 0.816600
# Epoch 197, CIFAR-10 Batch 1:  Loss:     0.0036 Validation Accuracy: 0.821800
# Epoch 197, CIFAR-10 Batch 2:  Loss:     0.0064 Validation Accuracy: 0.820400
# Epoch 197, CIFAR-10 Batch 3:  Loss:     0.0003 Validation Accuracy: 0.818800
# Epoch 197, CIFAR-10 Batch 4:  Loss:     0.0009 Validation Accuracy: 0.817200
# Epoch 197, CIFAR-10 Batch 5:  Loss:     0.0013 Validation Accuracy: 0.815800
# Epoch 198, CIFAR-10 Batch 1:  Loss:     0.0014 Validation Accuracy: 0.809600
# Epoch 198, CIFAR-10 Batch 2:  Loss:     0.0029 Validation Accuracy: 0.811400
# Epoch 198, CIFAR-10 Batch 3:  Loss:     0.0006 Validation Accuracy: 0.820200
# Epoch 198, CIFAR-10 Batch 4:  Loss:     0.0012 Validation Accuracy: 0.817800
# Epoch 198, CIFAR-10 Batch 5:  Loss:     0.0012 Validation Accuracy: 0.818600
# Epoch 199, CIFAR-10 Batch 1:  Loss:     0.0022 Validation Accuracy: 0.815600
# Epoch 199, CIFAR-10 Batch 2:  Loss:     0.0037 Validation Accuracy: 0.802400
# Epoch 199, CIFAR-10 Batch 3:  Loss:     0.0036 Validation Accuracy: 0.812600
# Epoch 199, CIFAR-10 Batch 4:  Loss:     0.0045 Validation Accuracy: 0.816000
# Epoch 199, CIFAR-10 Batch 5:  Loss:     0.0021 Validation Accuracy: 0.818800
# Epoch 200, CIFAR-10 Batch 1:  Loss:     0.0020 Validation Accuracy: 0.817000
# Epoch 200, CIFAR-10 Batch 2:  Loss:     0.0020 Validation Accuracy: 0.816000
# Epoch 200, CIFAR-10 Batch 3:  Loss:     0.0043 Validation Accuracy: 0.814400
# Epoch 200, CIFAR-10 Batch 4:  Loss:     0.0059 Validation Accuracy: 0.811600
# Epoch 200, CIFAR-10 Batch 5:  Loss:     0.0005 Validation Accuracy: 0.818000

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.8165174064351551

# %% [markdown]
# ## Why 50-70% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 70%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
